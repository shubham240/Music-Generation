# %%
from music21 import converter, instrument, note, chord, stream
import glob
import pickle
import numpy as np
from keras.utils import np_utils

# %%
midi = converter.parse("/content/drive/MyDrive/Music datasets/midi_songs/0fithos.mid")

# %%
midi
# Out:
# <music21.stream.Score 0x7fb6557dff10>

# %%
midi.show('midi')
# Out:
#                 <div id='midiPlayerDiv12857'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv12857');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
midi.show('text')
# Out:
# {0.0} <music21.stream.Part 0x7fb6556e7f10>
#     {0.0} <music21.instrument.Piano Piano>
#     {0.0} <music21.note.Rest rest>
#     {4.0} <music21.tempo.MetronomeMark allegretto Quarter=110.0>
#     {4.0} <music21.chord.Chord E3 A3>
#     {4.75} <music21.note.Rest rest>
#     {5.0} <music21.chord.Chord E3 A3>
#     {5.75} <music21.note.Rest rest>
#     {8.0} <music21.chord.Chord E3 B3>
#     {8.75} <music21.note.Rest rest>
#     {9.0} <music21.chord.Chord E3 B3>
#     {9.75} <music21.note.Rest rest>
#     {12.0} <music21.chord.Chord E3 C4>
#     {12.75} <music21.note.Rest rest>
#     {13.0} <music21.chord.Chord E3 C4>
#     {13.75} <music21.note.Rest rest>
#     {16.0} <music21.chord.Chord A3 D4>
#     {16.5} <music21.chord.Chord A3 D4>
#     {17.0} <music21.chord.Chord A3 D4>
#     {17.75} <music21.note.Rest rest>
#     {20.0} <music21.chord.Chord E4 A4>
#     {20.75} <music21.note.Rest rest>
#     {21.0} <music21.chord.Chord E4 A4>
#     {21.75} <music21.note.Rest rest>
#     {22.5} <music21.note.Note E>
#     {22.75} <music21.note.Note F>
#     {22.75} <music21.note.Note G#>
#     {22.75} <music21.note.Rest rest>
#     {23.0} <music21.note.Note A>
#     {23.75} <music21.note.Rest rest>
#     {24.0} <music21.chord.Chord F4 B4>
#     {24.75} <music21.note.Rest rest>
#     {25.0} <music21.chord.Chord F4 B4>
#     {25.75} <music21.note.Rest rest>
#     {26.5} <music21.note.Note E>
#     {26.75} <music21.note.Note F>
#     {26.75} <music21.note.Note G#>
#     {26.75} <music21.note.Rest rest>
#     {27.0} <music21.note.Note A>
#     {27.75} <music21.note.Rest rest>
#     {28.0} <music21.chord.Chord A4 C5>
#     {28.75} <music21.note.Rest rest>
#     {29.0} <music21.chord.Chord A4 C5>
#     {29.75} <music21.note.Rest rest>
#     {30.5} <music21.note.Note E>
#     {30.75} <music21.note.Note F>
#     {30.75} <music21.note.Note G#>
#     {30.75} <music21.note.Rest rest>
#     {31.0} <music21.note.Note A>
#     {31.75} <music21.note.Rest rest>
#     {32.0} <music21.chord.Chord B4 D5>
#     {32.5} <music21.chord.Chord B4 D5>
#     {33.0} <music21.chord.Chord B4 D5>
#     {33.75} <music21.note.Rest rest>
#     {34.5} <music21.note.Note E>
#     {34.75} <music21.note.Note F>
#     {34.75} <music21.note.Note G#>
#     {34.75} <music21.note.Rest rest>
#     {35.0} <music21.note.Note A>
#     {35.75} <music21.note.Rest rest>
#     {36.0} <music21.chord.Chord G4 B4 E-5>
#     {36.75} <music21.note.Rest rest>
#     {37.0} <music21.chord.Chord G4 B4 E-5>
#     {37.75} <music21.note.Rest rest>
#     {40.0} <music21.chord.Chord A4 C#5 F5>
#     {40.75} <music21.note.Rest rest>
#     {41.0} <music21.chord.Chord A4 C#5 F5>
#     {41.75} <music21.note.Rest rest>
#     {44.0} <music21.chord.Chord G4 B4 E-5>
#     {44.75} <music21.note.Rest rest>
#     {45.0} <music21.chord.Chord G4 B4 E-5>
#     {45.75} <music21.note.Rest rest>
#     {48.0} <music21.chord.Chord A4 C#5 F5>
#     {48.5} <music21.chord.Chord A4 C#5 F5>
#     {49.0} <music21.chord.Chord A4 C#5 F5>
#     {49.75} <music21.note.Rest rest>
#     {56.5} <music21.note.Note E>
#     {57.0} <music21.note.Note C>
#     {57.5} <music21.note.Note A>
#     {58.0} <music21.note.Rest rest>
#     {58.5} <music21.note.Note F>
#     {59.0} <music21.note.Note C>
#     {59.5} <music21.note.Note A>
#     {60.0} <music21.note.Rest rest>
#     {60.5} <music21.note.Note E>
#     {61.0} <music21.note.Note C>
#     {61.5} <music21.note.Note A>
#     {62.0} <music21.note.Note F>
#     {62.5} <music21.note.Note C>
#     {63.0} <music21.note.Note E>
#     {63.5} <music21.note.Note D>
#     {64.0} <music21.note.Note E>
#     {64.5} <music21.note.Note E->
#     {65.0} <music21.note.Note B>
#     {65.75} <music21.note.Rest rest>
#     {66.0} <music21.note.Note A>
#     {71.75} <music21.note.Rest rest>
#     {72.0} <music21.note.Note B>
#     {72.5} <music21.note.Note A>
#     {73.0} <music21.note.Note E>
#     {73.75} <music21.note.Rest rest>
#     {74.0} <music21.note.Note E->
#     {79.75} <music21.note.Rest rest>
#     {80.0} <music21.note.Note E>
#     {80.5} <music21.note.Note E->
#     {81.0} <music21.note.Note C>
#     {81.75} <music21.note.Rest rest>
#     {82.0} <music21.note.Note E>
#     {82.5} <music21.note.Note E->
#     {83.0} <music21.note.Note B>
#     {83.75} <music21.note.Rest rest>
#     {84.0} <music21.note.Note E>
#     {84.5} <music21.note.Note E->
#     {85.0} <music21.note.Note C>
#     {85.75} <music21.note.Rest rest>
#     {86.0} <music21.note.Note A>
#     {87.75} <music21.note.Rest rest>
#     {88.0} <music21.note.Note A>
#     {88.5} <music21.note.Note C>
#     {89.0} <music21.note.Note E>
#     {89.5} <music21.note.Note F>
#     {90.0} <music21.note.Note E>
#     {90.5} <music21.note.Note C>
#     {91.0} <music21.note.Note A>
#     {91.5} <music21.note.Note C>
#     {92.0} <music21.note.Note A>
#     {92.5} <music21.note.Note C>
#     {93.0} <music21.note.Note E>
#     {93.5} <music21.note.Note F#>
#     {94.0} <music21.note.Note E>
#     {94.5} <music21.note.Note C>
#     {95.0} <music21.note.Note A>
#     {95.5} <music21.note.Note C>
#     {96.0} <music21.note.Note A>
#     {96.5} <music21.note.Note C>
#     {97.0} <music21.note.Note E>
#     {97.5} <music21.note.Note F>
#     {98.0} <music21.note.Note E>
#     {98.5} <music21.note.Note C>
#     {99.0} <music21.note.Note A>
#     {99.5} <music21.note.Note C>
#     {100.0} <music21.note.Note A>
#     {100.5} <music21.note.Note C>
#     {101.0} <music21.note.Note E>
#     {101.5} <music21.note.Note F#>
#     {102.0} <music21.note.Note E>
#     {102.5} <music21.note.Note C>
#     {103.0} <music21.note.Note A>
#     {103.5} <music21.note.Note C>
#     {104.0} <music21.note.Note A>
#     {104.5} <music21.note.Note C>
#     {105.0} <music21.note.Note E>
#     {105.5} <music21.note.Note F>
#     {106.0} <music21.note.Note E>
#     {106.5} <music21.note.Note C>
#     {107.0} <music21.note.Note B>
#     {107.5} <music21.note.Note C>
#     {108.0} <music21.note.Note A>
#     {108.5} <music21.note.Note F>
#     {109.0} <music21.note.Note E>
#     {109.5} <music21.note.Note F>
#     {110.0} <music21.note.Note E>
#     {110.5} <music21.note.Note C>
#     {111.0} <music21.note.Note B>
#     {111.5} <music21.note.Note C>
#     {112.0} <music21.note.Note E>
#     {112.75} <music21.note.Rest rest>
#     {113.0} <music21.note.Note B>
#     {113.75} <music21.note.Rest rest>
#     {114.0} <music21.note.Note A>
#     {114.5} <music21.note.Note G>
#     {115.0} <music21.note.Note F>
#     {115.75} <music21.note.Rest rest>
#     {116.0} <music21.note.Note E>
#     {116.5} <music21.note.Note F>
#     {117.0} <music21.note.Note G>
#     {117.5} <music21.note.Note D>
#     {118.0} <music21.note.Note F>
#     {118.75} <music21.note.Rest rest>
#     {119.0} <music21.note.Note E>
#     {119.5} <music21.note.Note D>
#     {120.0} <music21.note.Note E>
#     {120.75} <music21.note.Rest rest>
#     {121.0} <music21.note.Note B>
#     {121.5} <music21.note.Note C>
#     {122.0} <music21.note.Note D>
#     {122.75} <music21.note.Rest rest>
#     {123.0} <music21.note.Note C>
#     {123.5} <music21.note.Note B>
#     {124.0} <music21.note.Note C>
#     {124.5} <music21.note.Note B>
#     {125.0} <music21.note.Note C>
#     {125.5} <music21.note.Note A>
#     {126.0} <music21.note.Note F>
#     {126.75} <music21.note.Rest rest>
#     {127.0} <music21.note.Note G>
#     {127.75} <music21.note.Rest rest>
#     {128.0} <music21.chord.Chord E4 A4>
#     {128.75} <music21.note.Rest rest>
#     {129.0} <music21.chord.Chord E4 A4>
#     {129.75} <music21.note.Rest rest>
#     {130.0} <music21.note.Note G>
#     {130.5} <music21.note.Note F#>
#     {131.0} <music21.note.Note E>
#     {131.75} <music21.note.Rest rest>
#     {132.0} <music21.chord.Chord A4 B4>
#     {132.75} <music21.note.Rest rest>
#     {133.0} <music21.chord.Chord A4 B4>
#     {133.75} <music21.note.Rest rest>
#     {134.0} <music21.note.Note E->
#     {134.0} <music21.note.Note D>
#     {134.3333} <music21.note.Rest rest>
#     {134.5} <music21.note.Note C>
#     {135.0} <music21.note.Note D>
#     {135.5} <music21.note.Note E>
#     {136.0} <music21.chord.Chord A4 C5>
#     {136.75} <music21.note.Rest rest>
#     {137.0} <music21.chord.Chord A4 C5>
#     {137.75} <music21.note.Rest rest>
#     {138.0} <music21.note.Note C>
#     {138.5} <music21.note.Note G#>
#     {139.0} <music21.note.Note A>
#     {139.5} <music21.note.Note C>
#     {140.0} <music21.chord.Chord B4 D5>
#     {140.5} <music21.chord.Chord B4 D5>
#     {141.0} <music21.chord.Chord B4 D5>
#     {141.75} <music21.note.Rest rest>
#     {142.0} <music21.note.Note C>
#     {142.25} <music21.note.Note G>
#     {142.5} <music21.note.Note G#>
#     {142.75} <music21.note.Note B>
#     {143.0} <music21.note.Note A>
#     {143.75} <music21.note.Rest rest>
#     {144.0} <music21.note.Note E>
#     {144.75} <music21.note.Rest rest>
#     {145.0} <music21.note.Note B>
#     {145.75} <music21.note.Rest rest>
#     {146.0} <music21.note.Note A>
#     {146.5} <music21.note.Note G>
#     {147.0} <music21.note.Note F>
#     {147.75} <music21.note.Rest rest>
#     {148.0} <music21.note.Note E>
#     {148.5} <music21.note.Note F>
#     {149.0} <music21.note.Note G>
#     {149.5} <music21.note.Note D>
#     {150.0} <music21.note.Note F>
#     {150.75} <music21.note.Rest rest>
#     {151.0} <music21.note.Note E>
#     {151.5} <music21.note.Note D>
#     {152.0} <music21.note.Note E>
#     {152.75} <music21.note.Rest rest>
#     {153.0} <music21.note.Note B>
#     {153.5} <music21.note.Note C>
#     {154.0} <music21.note.Note D>
#     {154.75} <music21.note.Rest rest>
#     {155.0} <music21.note.Note C>
#     {155.5} <music21.note.Note B>
#     {156.0} <music21.note.Note C>
#     {156.5} <music21.note.Note B->
#     {157.0} <music21.note.Note C>
#     {157.5} <music21.note.Note G#>
#     {158.0} <music21.note.Note F>
#     {158.75} <music21.note.Rest rest>
#     {159.0} <music21.note.Note G>
#     {159.75} <music21.note.Rest rest>
#     {160.0} <music21.chord.Chord C4 E4 A4>
#     {160.75} <music21.note.Rest rest>
#     {161.0} <music21.chord.Chord C4 E4 A4>
#     {161.75} <music21.note.Rest rest>
#     {164.0} <music21.chord.Chord D4 F#4 B4>
#     {164.75} <music21.note.Rest rest>
#     {165.0} <music21.chord.Chord D4 F#4 B4>
#     {165.75} <music21.note.Rest rest>
#     {168.0} <music21.chord.Chord E4 G4 C5>
#     {168.75} <music21.note.Rest rest>
#     {169.0} <music21.chord.Chord E4 G4 C5>
#     {169.75} <music21.note.Rest rest>
#     {172.0} <music21.chord.Chord F#4 A4 D5>
#     {172.5} <music21.chord.Chord F#4 A4 D5>
#     {173.0} <music21.chord.Chord F#4 A4 D5>
#     {173.75} <music21.note.Rest rest>
#     {177.0} <music21.chord.Chord F4 G#4 C5>
#     {177.75} <music21.note.Rest rest>
#     {178.5} <music21.chord.Chord F4 G#4 C#5>
#     {179.0} <music21.chord.Chord F4 G#4 C#5>
#     {179.75} <music21.note.Rest rest>
#     {180.5} <music21.chord.Chord F4 G#4 C5>
#     {181.0} <music21.chord.Chord F4 G#4 C5>
#     {181.75} <music21.note.Rest rest>
#     {182.5} <music21.chord.Chord E4 G#4 B4>
#     {183.0} <music21.note.Rest rest>
#     {183.5} <music21.chord.Chord E4 G#4 C#5>
#     {184.0} <music21.note.Rest rest>
#     {185.0} <music21.chord.Chord F#4 B4 D5>
#     {185.75} <music21.note.Rest rest>
#     {186.5} <music21.chord.Chord G4 B4 D5>
#     {187.0} <music21.chord.Chord G4 B4 D5>
#     {187.75} <music21.note.Rest rest>
#     {188.5} <music21.chord.Chord F#4 B4 D5>
#     {189.0} <music21.chord.Chord F#4 B4 D5>
#     {189.75} <music21.note.Rest rest>
#     {190.0} <music21.chord.Chord F#4 B4 D5>
#     {190.75} <music21.note.Rest rest>
#     {191.0} <music21.chord.Chord F4 C5 D5>
#     {191.75} <music21.note.Rest rest>
#     {192.5} <music21.note.Note G>
#     {193.0} <music21.note.Note G>
#     {193.5} <music21.note.Note G>
#     {194.0} <music21.note.Note B->
#     {194.0} <music21.note.Note G#>
#     {194.3333} <music21.note.Rest rest>
#     {194.5} <music21.note.Note G>
#     {195.0} <music21.note.Note G>
#     {195.5} <music21.note.Note G>
#     {196.0} <music21.note.Note B->
#     {196.0} <music21.note.Note G#>
#     {196.3333} <music21.note.Rest rest>
#     {196.5} <music21.note.Note G>
#     {197.0} <music21.note.Note B->
#     {197.5} <music21.note.Note G#>
#     {198.0} <music21.note.Note G>
#     {198.5} <music21.note.Note G#>
#     {199.0} <music21.note.Note G>
#     {199.5} <music21.note.Note F>
#     {200.0} <music21.note.Rest rest>
#     {200.5} <music21.note.Note G>
#     {201.0} <music21.note.Note G>
#     {201.5} <music21.note.Note G>
#     {202.0} <music21.note.Note B->
#     {202.0} <music21.note.Note G#>
#     {202.3333} <music21.note.Rest rest>
#     {202.5} <music21.note.Note G>
#     {203.0} <music21.note.Note G>
#     {203.5} <music21.note.Note G>
#     {204.0} <music21.note.Note B->
#     {204.0} <music21.note.Note G#>
#     {204.3333} <music21.note.Rest rest>
#     {204.5} <music21.note.Note G>
#     {205.0} <music21.note.Note B->
#     {205.5} <music21.note.Note G#>
#     {206.0} <music21.note.Note G>
#     {206.5} <music21.note.Note G#>
#     {207.0} <music21.note.Note G>
#     {207.5} <music21.note.Note E->
#     {208.0} <music21.note.Rest rest>
#     {208.5} <music21.note.Note A>
#     {209.0} <music21.note.Note A>
#     {209.5} <music21.note.Note A>
#     {210.0} <music21.note.Note C>
#     {210.0} <music21.note.Note B->
#     {210.3333} <music21.note.Rest rest>
#     {210.5} <music21.note.Note A>
#     {211.0} <music21.note.Note A>
#     {211.5} <music21.note.Note A>
#     {212.0} <music21.note.Note C>
#     {212.0} <music21.note.Note B->
#     {212.3333} <music21.note.Rest rest>
#     {212.5} <music21.note.Note A>
#     {213.0} <music21.note.Note C>
#     {213.5} <music21.note.Note B->
#     {214.0} <music21.note.Note A>
#     {214.5} <music21.note.Note B->
#     {215.0} <music21.note.Note A>
#     {215.5} <music21.note.Note G>
#     {216.0} <music21.note.Rest rest>
#     {216.5} <music21.note.Note A>
#     {217.0} <music21.note.Note A>
#     {217.5} <music21.note.Note A>
#     {218.0} <music21.note.Note C>
#     {218.0} <music21.note.Note B->
#     {218.3333} <music21.note.Rest rest>
#     {218.5} <music21.note.Note A>
#     {219.0} <music21.note.Note A>
#     {219.5} <music21.note.Note A>
#     {220.0} <music21.meter.TimeSignature 2/4>
#     {220.0} <music21.note.Rest rest>
#     {220.5} <music21.note.Note F#>
#     {220.75} <music21.note.Note B->
#     {221.0} <music21.note.Note F#>
#     {221.5} <music21.note.Note F>
#     {222.0} <music21.meter.TimeSignature 4/4>
#     {222.0} <music21.note.Note E>
#     {222.75} <music21.note.Rest rest>
#     {223.0} <music21.note.Note E>
#     {223.5} <music21.note.Note F>
#     {224.0} <music21.note.Note E>
#     {224.75} <music21.note.Rest rest>
#     {225.0} <music21.note.Note E>
#     {225.5} <music21.note.Note F>
#     {226.0} <music21.note.Note E>
#     {226.5} <music21.note.Note C>
#     {227.0} <music21.note.Note A>
#     {227.5} <music21.note.Note F>
#     {228.0} <music21.note.Note E>
#     {228.5} <music21.note.Note C>
#     {229.0} <music21.note.Note A>
#     {229.5} <music21.note.Note F>
#     {230.0} <music21.note.Note E>
#     {230.5} <music21.note.Note C>
#     {231.0} <music21.note.Note A>
#     {231.5} <music21.note.Note F>
#     {232.0} <music21.note.Note E>
#     {237.75} <music21.note.Rest rest>
#     {238.0} <music21.chord.Chord E3 A3>
#     {238.75} <music21.note.Rest rest>
#     {239.0} <music21.chord.Chord E3 A3>
#     {239.75} <music21.note.Rest rest>
#     {242.0} <music21.chord.Chord E3 B3>
#     {242.75} <music21.note.Rest rest>
#     {243.0} <music21.chord.Chord E3 B3>
#     {243.75} <music21.note.Rest rest>
#     {246.0} <music21.chord.Chord E3 C4>
#     {246.75} <music21.note.Rest rest>
#     {247.0} <music21.chord.Chord E3 C4>
#     {247.75} <music21.note.Rest rest>
#     {250.0} <music21.chord.Chord A3 D4>
#     {250.5} <music21.chord.Chord A3 D4>
#     {251.0} <music21.chord.Chord A3 D4>
#     {251.75} <music21.note.Rest rest>
#     {254.0} <music21.chord.Chord E4 A4>
#     {254.75} <music21.note.Rest rest>
#     {255.0} <music21.chord.Chord E4 A4>
#     {255.75} <music21.note.Rest rest>
#     {256.5} <music21.note.Note E>
#     {256.75} <music21.note.Note F>
#     {256.75} <music21.note.Note G#>
#     {256.75} <music21.note.Rest rest>
#     {257.0} <music21.note.Note A>
#     {257.75} <music21.note.Rest rest>
#     {258.0} <music21.chord.Chord F4 B4>
#     {258.75} <music21.note.Rest rest>
#     {259.0} <music21.chord.Chord F4 B4>
#     {259.75} <music21.note.Rest rest>
#     {260.5} <music21.note.Note E>
#     {260.75} <music21.note.Note F>
#     {260.75} <music21.note.Note G#>
#     {260.75} <music21.note.Rest rest>
#     {261.0} <music21.note.Note A>
#     {261.75} <music21.note.Rest rest>
#     {262.0} <music21.chord.Chord A4 C5>
#     {262.75} <music21.note.Rest rest>
#     {263.0} <music21.chord.Chord A4 C5>
#     {263.75} <music21.note.Rest rest>
#     {264.5} <music21.note.Note E>
#     {264.75} <music21.note.Note F>
#     {264.75} <music21.note.Note G#>
#     {264.75} <music21.note.Rest rest>
#     {265.0} <music21.note.Note A>
#     {265.75} <music21.note.Rest rest>
#     {266.0} <music21.chord.Chord B4 D5>
#     {266.5} <music21.chord.Chord B4 D5>
#     {267.0} <music21.chord.Chord B4 D5>
#     {267.75} <music21.note.Rest rest>
#     {268.5} <music21.note.Note E>
#     {268.75} <music21.note.Note F>
#     {268.75} <music21.note.Note G#>
#     {268.75} <music21.note.Rest rest>
#     {269.0} <music21.note.Note A>
#     {269.75} <music21.note.Rest rest>
#     {270.0} <music21.chord.Chord G4 B4 E-5>
#     {270.75} <music21.note.Rest rest>
#     {271.0} <music21.chord.Chord G4 B4 E-5>
#     {271.75} <music21.note.Rest rest>
#     {274.0} <music21.chord.Chord A4 C#5 F5>
#     {274.75} <music21.note.Rest rest>
#     {275.0} <music21.chord.Chord A4 C#5 F5>
#     {275.75} <music21.note.Rest rest>
#     {278.0} <music21.chord.Chord G4 B4 E-5>
#     {278.75} <music21.note.Rest rest>
#     {279.0} <music21.chord.Chord G4 B4 E-5>
#     {279.75} <music21.note.Rest rest>
#     {282.0} <music21.chord.Chord A4 C#5 F5>
#     {282.5} <music21.chord.Chord A4 C#5 F5>
#     {283.0} <music21.chord.Chord A4 C#5 F5>
#     {283.75} <music21.note.Rest rest>
#     {290.5} <music21.note.Note E>
#     {291.0} <music21.note.Note C>
#     {291.5} <music21.note.Note A>
#     {292.0} <music21.note.Rest rest>
#     {292.5} <music21.note.Note F>
#     {293.0} <music21.note.Note C>
#     {293.5} <music21.note.Note A>
#     {294.0} <music21.note.Rest rest>
#     {294.5} <music21.note.Note E>
#     {295.0} <music21.note.Note C>
#     {295.5} <music21.note.Note A>
#     {296.0} <music21.note.Note F>
#     {296.5} <music21.note.Note C>
#     {297.0} <music21.note.Note E>
#     {297.5} <music21.note.Note D>
#     {298.0} <music21.note.Note E>
#     {298.5} <music21.note.Note E->
#     {299.0} <music21.note.Note B>
#     {299.75} <music21.note.Rest rest>
#     {300.0} <music21.note.Note A>
#     {305.75} <music21.note.Rest rest>
#     {306.0} <music21.note.Note B>
#     {306.5} <music21.note.Note A>
#     {307.0} <music21.note.Note E>
#     {307.75} <music21.note.Rest rest>
#     {308.0} <music21.note.Note E->
#     {313.75} <music21.note.Rest rest>
#     {314.0} <music21.note.Note E>
#     {314.5} <music21.note.Note E->
#     {315.0} <music21.note.Note C>
#     {315.75} <music21.note.Rest rest>
#     {316.0} <music21.note.Note E>
#     {316.5} <music21.note.Note E->
#     {317.0} <music21.note.Note B>
#     {317.75} <music21.note.Rest rest>
#     {318.0} <music21.note.Note E>
#     {318.5} <music21.note.Note E->
#     {319.0} <music21.note.Note C>
#     {319.75} <music21.note.Rest rest>
#     {320.0} <music21.note.Note A>
#     {321.75} <music21.note.Rest rest>
#     {322.0} <music21.note.Note A>
#     {322.5} <music21.note.Note C>
#     {323.0} <music21.note.Note E>
#     {323.5} <music21.note.Note F>
#     {324.0} <music21.note.Note E>
#     {324.5} <music21.note.Note C>
#     {325.0} <music21.note.Note A>
#     {325.5} <music21.note.Note C>
#     {326.0} <music21.note.Note A>
#     {326.5} <music21.note.Note C>
#     {327.0} <music21.note.Note E>
#     {327.5} <music21.note.Note F#>
#     {328.0} <music21.note.Note E>
#     {328.5} <music21.note.Note C>
#     {329.0} <music21.note.Note A>
#     {329.5} <music21.note.Note C>
#     {330.0} <music21.note.Note A>
#     {330.5} <music21.note.Note C>
#     {331.0} <music21.note.Note E>
#     {331.5} <music21.note.Note F>
#     {332.0} <music21.note.Note E>
#     {332.5} <music21.note.Note C>
#     {333.0} <music21.note.Note A>
#     {333.5} <music21.note.Note C>
#     {334.0} <music21.note.Note A>
#     {334.5} <music21.note.Note C>
#     {335.0} <music21.note.Note E>
#     {335.5} <music21.note.Note F#>
#     {336.0} <music21.note.Note E>
#     {336.5} <music21.note.Note C>
#     {337.0} <music21.note.Note A>
#     {337.5} <music21.note.Note C>
#     {338.0} <music21.note.Note A>
#     {338.5} <music21.note.Note C>
#     {339.0} <music21.note.Note E>
#     {339.5} <music21.note.Note F>
#     {340.0} <music21.note.Note E>
#     {340.5} <music21.note.Note C>
#     {341.0} <music21.note.Note B>
#     {341.5} <music21.note.Note C>
#     {342.0} <music21.note.Note A>
#     {342.5} <music21.note.Note F>
#     {343.0} <music21.note.Note E>
#     {343.5} <music21.note.Note F>
#     {344.0} <music21.note.Note E>
#     {344.5} <music21.note.Note C>
#     {345.0} <music21.note.Note B>
#     {345.5} <music21.note.Note C>
#     {346.0} <music21.note.Note E>
#     {346.75} <music21.note.Rest rest>
#     {347.0} <music21.note.Note B>
#     {347.75} <music21.note.Rest rest>
#     {348.0} <music21.note.Note A>
#     {348.5} <music21.note.Note G>
#     {349.0} <music21.note.Note F>
#     {349.75} <music21.note.Rest rest>
#     {350.0} <music21.note.Note E>
#     {350.5} <music21.note.Note F>
#     {351.0} <music21.note.Note G>
#     {351.5} <music21.note.Note D>
#     {352.0} <music21.note.Note F>
#     {352.75} <music21.note.Rest rest>
#     {353.0} <music21.note.Note E>
#     {353.5} <music21.note.Note D>
#     {354.0} <music21.note.Note E>
#     {354.75} <music21.note.Rest rest>
#     {355.0} <music21.note.Note B>
#     {355.5} <music21.note.Note C>
#     {356.0} <music21.note.Note D>
#     {356.75} <music21.note.Rest rest>
#     {357.0} <music21.note.Note C>
#     {357.5} <music21.note.Note B>
#     {358.0} <music21.note.Note C>
#     {358.5} <music21.note.Note B>
#     {359.0} <music21.note.Note C>
#     {359.5} <music21.note.Note A>
#     {360.0} <music21.note.Note F>
#     {360.75} <music21.note.Rest rest>
#     {361.0} <music21.note.Note G>
#     {361.75} <music21.note.Rest rest>
#     {362.0} <music21.chord.Chord E4 A4>
#     {362.75} <music21.note.Rest rest>
#     {363.0} <music21.chord.Chord E4 A4>
#     {363.75} <music21.note.Rest rest>
#     {364.0} <music21.note.Note G>
#     {364.5} <music21.note.Note F#>
#     {365.0} <music21.note.Note E>
#     {365.75} <music21.note.Rest rest>
#     {366.0} <music21.chord.Chord A4 B4>
#     {366.75} <music21.note.Rest rest>
#     {367.0} <music21.chord.Chord A4 B4>
#     {367.75} <music21.note.Rest rest>
#     {368.0} <music21.note.Note E->
#     {368.0} <music21.note.Note D>
#     {368.3333} <music21.note.Rest rest>
#     {368.5} <music21.note.Note C>
#     {369.0} <music21.note.Note D>
#     {369.5} <music21.note.Note E>
#     {370.0} <music21.chord.Chord A4 C5>
#     {370.75} <music21.note.Rest rest>
#     {371.0} <music21.chord.Chord A4 C5>
#     {371.75} <music21.note.Rest rest>
#     {372.0} <music21.note.Note C>
#     {372.5} <music21.note.Note G#>
#     {373.0} <music21.note.Note A>
#     {373.5} <music21.note.Note C>
#     {374.0} <music21.chord.Chord B4 D5>
#     {374.5} <music21.chord.Chord B4 D5>
#     {375.0} <music21.chord.Chord B4 D5>
#     {375.75} <music21.note.Rest rest>
#     {376.0} <music21.note.Note C>
#     {376.25} <music21.note.Note G>
#     {376.5} <music21.note.Note G#>
#     {376.75} <music21.note.Note B>
#     {377.0} <music21.note.Note A>
#     {377.75} <music21.note.Rest rest>
#     {378.0} <music21.note.Note E>
#     {378.75} <music21.note.Rest rest>
#     {379.0} <music21.note.Note B>
#     {379.75} <music21.note.Rest rest>
#     {380.0} <music21.note.Note A>
#     {380.5} <music21.note.Note G>
#     {381.0} <music21.note.Note F>
#     {381.75} <music21.note.Rest rest>
#     {382.0} <music21.note.Note E>
#     {382.5} <music21.note.Note F>
#     {383.0} <music21.note.Note G>
#     {383.5} <music21.note.Note D>
#     {384.0} <music21.note.Note F>
#     {384.75} <music21.note.Rest rest>
#     {385.0} <music21.note.Note E>
#     {385.5} <music21.note.Note D>
#     {386.0} <music21.note.Note E>
#     {386.75} <music21.note.Rest rest>
#     {387.0} <music21.note.Note B>
#     {387.5} <music21.note.Note C>
#     {388.0} <music21.note.Note D>
#     {388.75} <music21.note.Rest rest>
#     {389.0} <music21.note.Note C>
#     {389.5} <music21.note.Note B>
#     {390.0} <music21.note.Note C>
#     {390.5} <music21.note.Note B->
#     {391.0} <music21.note.Note C>
#     {391.5} <music21.note.Note G#>
#     {392.0} <music21.note.Note F>
#     {392.75} <music21.note.Rest rest>
#     {393.0} <music21.note.Note G>
#     {393.75} <music21.note.Rest rest>
#     {394.0} <music21.chord.Chord C4 E4 A4>
#     {394.75} <music21.note.Rest rest>
#     {395.0} <music21.chord.Chord C4 E4 A4>
#     {395.75} <music21.note.Rest rest>
#     {398.0} <music21.chord.Chord D4 F#4 B4>
#     {398.75} <music21.note.Rest rest>
#     {399.0} <music21.chord.Chord D4 F#4 B4>
#     {399.75} <music21.note.Rest rest>
#     {402.0} <music21.chord.Chord E4 G4 C5>
#     {402.75} <music21.note.Rest rest>
#     {403.0} <music21.chord.Chord E4 G4 C5>
#     {403.75} <music21.note.Rest rest>
#     {406.0} <music21.chord.Chord F#4 A4 D5>
#     {406.5} <music21.chord.Chord F#4 A4 D5>
#     {407.0} <music21.chord.Chord F#4 A4 D5>
#     {407.75} <music21.note.Rest rest>
#     {411.0} <music21.chord.Chord F4 G#4 C5>
#     {411.75} <music21.note.Rest rest>
#     {412.5} <music21.chord.Chord F4 G#4 C#5>
#     {413.0} <music21.chord.Chord F4 G#4 C#5>
#     {413.75} <music21.note.Rest rest>
#     {414.5} <music21.chord.Chord F4 G#4 C5>
#     {415.0} <music21.chord.Chord F4 G#4 C5>
#     {415.75} <music21.note.Rest rest>
#     {416.5} <music21.chord.Chord E4 G#4 B4>
#     {417.0} <music21.note.Rest rest>
#     {417.5} <music21.chord.Chord E4 G#4 C#5>
#     {418.0} <music21.note.Rest rest>
#     {419.0} <music21.chord.Chord F#4 B4 D5>
#     {419.75} <music21.note.Rest rest>
#     {420.5} <music21.chord.Chord G4 B4 D5>
#     {421.0} <music21.chord.Chord G4 B4 D5>
#     {421.75} <music21.note.Rest rest>
#     {422.5} <music21.chord.Chord F#4 B4 D5>
#     {423.0} <music21.chord.Chord F#4 B4 D5>
#     {423.75} <music21.note.Rest rest>
#     {424.0} <music21.chord.Chord F#4 B4 D5>
#     {424.75} <music21.note.Rest rest>
#     {425.0} <music21.chord.Chord F4 C5 D5>
#     {425.75} <music21.note.Rest rest>
#     {426.5} <music21.note.Note G>
#     {427.0} <music21.note.Note G>
#     {427.5} <music21.note.Note G>
#     {428.0} <music21.note.Note B->
#     {428.0} <music21.note.Note G#>
#     {428.3333} <music21.note.Rest rest>
#     {428.5} <music21.note.Note G>
#     {429.0} <music21.note.Note G>
#     {429.5} <music21.note.Note G>
#     {430.0} <music21.note.Note B->
#     {430.0} <music21.note.Note G#>
#     {430.3333} <music21.note.Rest rest>
#     {430.5} <music21.note.Note G>
#     {431.0} <music21.note.Note B->
#     {431.5} <music21.note.Note G#>
#     {432.0} <music21.note.Note G>
#     {432.5} <music21.note.Note G#>
#     {433.0} <music21.note.Note G>
#     {433.5} <music21.note.Note F>
#     {434.0} <music21.note.Rest rest>
#     {434.5} <music21.note.Note G>
#     {435.0} <music21.note.Note G>
#     {435.5} <music21.note.Note G>
#     {436.0} <music21.note.Note B->
#     {436.0} <music21.note.Note G#>
#     {436.3333} <music21.note.Rest rest>
#     {436.5} <music21.note.Note G>
#     {437.0} <music21.note.Note G>
#     {437.5} <music21.note.Note G>
#     {438.0} <music21.note.Note B->
#     {438.0} <music21.note.Note G#>
#     {438.3333} <music21.note.Rest rest>
#     {438.5} <music21.note.Note G>
#     {439.0} <music21.note.Note B->
#     {439.5} <music21.note.Note G#>
#     {440.0} <music21.note.Note G>
#     {440.5} <music21.note.Note G#>
#     {441.0} <music21.note.Note G>
#     {441.5} <music21.note.Note E->
#     {442.0} <music21.note.Rest rest>
#     {442.5} <music21.note.Note A>
#     {443.0} <music21.note.Note A>
#     {443.5} <music21.note.Note A>
#     {444.0} <music21.note.Note C>
#     {444.0} <music21.note.Note B->
#     {444.3333} <music21.note.Rest rest>
#     {444.5} <music21.note.Note A>
#     {445.0} <music21.note.Note A>
#     {445.5} <music21.note.Note A>
#     {446.0} <music21.note.Note C>
#     {446.0} <music21.note.Note B->
#     {446.3333} <music21.note.Rest rest>
#     {446.5} <music21.note.Note A>
#     {447.0} <music21.note.Note C>
#     {447.5} <music21.note.Note B->
#     {448.0} <music21.note.Note A>
#     {448.5} <music21.note.Note B->
#     {449.0} <music21.note.Note A>
#     {449.5} <music21.note.Note G>
#     {450.0} <music21.note.Rest rest>
#     {450.5} <music21.note.Note A>
#     {451.0} <music21.note.Note A>
#     {451.5} <music21.note.Note A>
#     {452.0} <music21.note.Note C>
#     {452.0} <music21.note.Note B->
#     {452.3333} <music21.note.Rest rest>
#     {452.5} <music21.note.Note A>
#     {453.0} <music21.note.Note A>
#     {453.5} <music21.note.Note A>
#     {454.0} <music21.meter.TimeSignature 2/4>
#     {454.0} <music21.note.Rest rest>
#     {454.5} <music21.note.Note F#>
#     {454.75} <music21.note.Note B->
#     {455.0} <music21.note.Note F#>
#     {455.5} <music21.note.Note F>
#     {456.0} <music21.meter.TimeSignature 4/4>
#     {456.0} <music21.note.Note E>
#     {456.75} <music21.note.Rest rest>
#     {457.0} <music21.note.Note E>
#     {457.5} <music21.note.Note F>
#     {458.0} <music21.note.Note E>
#     {458.75} <music21.note.Rest rest>
#     {459.0} <music21.note.Note E>
#     {459.5} <music21.note.Note F>
#     {460.0} <music21.note.Note E>
#     {460.5} <music21.note.Note C>
#     {461.0} <music21.note.Note A>
#     {461.5} <music21.note.Note F>
#     {462.0} <music21.note.Note E>
#     {462.5} <music21.note.Note C>
#     {463.0} <music21.note.Note A>
#     {463.5} <music21.note.Note F>
#     {464.0} <music21.note.Note E>
#     {464.5} <music21.note.Note C>
#     {465.0} <music21.note.Note A>
#     {465.5} <music21.note.Note F>
#     {466.0} <music21.note.Note E>
#     {471.75} <music21.note.Rest rest>
#     {472.0} <music21.chord.Chord E4 A4>
#     {472.75} <music21.note.Rest rest>
#     {473.0} <music21.chord.Chord E4 A4>
# {0.0} <music21.stream.Part 0x7fb62161afd0>
#     {0.0} <music21.instrument.Piano Piano>
#     {0.0} <music21.note.Rest rest>
#     {4.0} <music21.note.Note E>
#     {4.75} <music21.note.Rest rest>
#     {12.0} <music21.note.Note E>
#     {12.75} <music21.note.Rest rest>
#     {20.0} <music21.note.Note E>
#     {20.75} <music21.note.Rest rest>
#     {28.0} <music21.note.Note E>
#     {28.75} <music21.note.Rest rest>
#     {220.0} <music21.meter.TimeSignature 2/4>
#     {222.0} <music21.meter.TimeSignature 4/4>
#     {238.0} <music21.note.Note E>
#     {238.75} <music21.note.Rest rest>
#     {246.0} <music21.note.Note E>
#     {246.75} <music21.note.Rest rest>
#     {254.0} <music21.note.Note E>
#     {254.75} <music21.note.Rest rest>
#     {262.0} <music21.note.Note E>
#     {262.75} <music21.note.Rest rest>
#     {454.0} <music21.meter.TimeSignature 2/4>
#     {456.0} <music21.meter.TimeSignature 4/4>
#     {472.0} <music21.note.Note E>
# {0.0} <music21.stream.Part 0x7fb622affa90>
#     {0.0} <music21.instrument.Piano Piano>
#     {0.0} <music21.note.Rest rest>
#     {4.0} <music21.chord.Chord A1 E2>
#     {4.75} <music21.note.Rest rest>
#     {5.0} <music21.chord.Chord A1 E2>
#     {5.5} <music21.chord.Chord A1 E2>
#     {6.0} <music21.chord.Chord A1 E2>
#     {6.75} <music21.note.Rest rest>
#     {7.0} <music21.chord.Chord A1 E2>
#     {7.5} <music21.chord.Chord A1 E2>
#     {8.0} <music21.chord.Chord A1 E2>
#     {8.75} <music21.note.Rest rest>
#     {9.0} <music21.chord.Chord A1 E2>
#     {9.5} <music21.chord.Chord A1 E2>
#     {10.0} <music21.chord.Chord A1 E2>
#     {10.75} <music21.note.Rest rest>
#     {11.0} <music21.chord.Chord A1 E2>
#     {11.5} <music21.chord.Chord A1 E2>
#     {12.0} <music21.chord.Chord A1 E2>
#     {12.75} <music21.note.Rest rest>
#     {13.0} <music21.chord.Chord A1 E2>
#     {13.5} <music21.chord.Chord A1 E2>
#     {14.0} <music21.chord.Chord A1 E2>
#     {14.75} <music21.note.Rest rest>
#     {15.0} <music21.chord.Chord A1 E2>
#     {15.5} <music21.chord.Chord A1 E2>
#     {16.0} <music21.chord.Chord A1 E2>
#     {16.75} <music21.note.Rest rest>
#     {17.0} <music21.chord.Chord A1 E2>
#     {17.5} <music21.chord.Chord A1 E2>
#     {18.0} <music21.chord.Chord A1 E2>
#     {18.75} <music21.note.Rest rest>
#     {19.0} <music21.chord.Chord A1 E2>
#     {19.5} <music21.chord.Chord A1 E2>
#     {20.0} <music21.chord.Chord A1 E2>
#     {20.75} <music21.note.Rest rest>
#     {21.0} <music21.chord.Chord A1 E2>
#     {21.5} <music21.chord.Chord A1 E2>
#     {22.0} <music21.chord.Chord A1 E2>
#     {22.75} <music21.note.Rest rest>
#     {23.0} <music21.chord.Chord A1 E2>
#     {23.5} <music21.chord.Chord A1 E2>
#     {24.0} <music21.chord.Chord A1 E2>
#     {24.75} <music21.note.Rest rest>
#     {25.0} <music21.chord.Chord A1 E2>
#     {25.5} <music21.chord.Chord A1 E2>
#     {26.0} <music21.chord.Chord A1 E2>
#     {26.75} <music21.note.Rest rest>
#     {27.0} <music21.chord.Chord A1 E2>
#     {27.5} <music21.chord.Chord A1 E2>
#     {28.0} <music21.chord.Chord A1 E2>
#     {28.75} <music21.note.Rest rest>
#     {29.0} <music21.chord.Chord A1 E2>
#     {29.5} <music21.chord.Chord A1 E2>
#     {30.0} <music21.chord.Chord A1 E2>
#     {30.75} <music21.note.Rest rest>
#     {31.0} <music21.chord.Chord A1 E2>
#     {31.5} <music21.chord.Chord A1 E2>
#     {32.0} <music21.chord.Chord A1 E2>
#     {32.75} <music21.note.Rest rest>
#     {33.0} <music21.chord.Chord A1 E2>
#     {33.5} <music21.chord.Chord A1 E2>
#     {34.0} <music21.chord.Chord A1 E2>
#     {34.75} <music21.note.Rest rest>
#     {35.0} <music21.chord.Chord A1 E2>
#     {35.5} <music21.chord.Chord A1 E2>
#     {36.0} <music21.note.Note E->
#     {37.75} <music21.note.Rest rest>
#     {38.0} <music21.note.Note B>
#     {38.75} <music21.note.Rest rest>
#     {39.0} <music21.note.Note G>
#     {39.75} <music21.note.Rest rest>
#     {40.0} <music21.note.Note F#>
#     {43.75} <music21.note.Rest rest>
#     {44.0} <music21.note.Note E->
#     {46.5} <music21.note.Note G>
#     {47.0} <music21.note.Note B>
#     {47.5} <music21.note.Note E->
#     {48.0} <music21.note.Note G#>
#     {48.75} <music21.note.Rest rest>
#     {49.0} <music21.note.Note F>
#     {51.75} <music21.note.Rest rest>
#     {52.0} <music21.note.Note F>
#     {52.75} <music21.note.Rest rest>
#     {53.0} <music21.note.Note F>
#     {53.75} <music21.note.Rest rest>
#     {54.0} <music21.note.Note F>
#     {54.5} <music21.note.Note F>
#     {55.0} <music21.note.Note F>
#     {55.75} <music21.note.Rest rest>
#     {56.0} <music21.chord.Chord E3 A3>
#     {56.5} <music21.chord.Chord E3 A3>
#     {57.0} <music21.chord.Chord E3 A3>
#     {57.5} <music21.chord.Chord E3 A3>
#     {58.0} <music21.chord.Chord F3 A3>
#     {58.5} <music21.chord.Chord F3 A3>
#     {59.0} <music21.chord.Chord F3 A3>
#     {59.5} <music21.chord.Chord F3 A3>
#     {60.0} <music21.chord.Chord E3 A3>
#     {60.5} <music21.chord.Chord E3 A3>
#     {61.0} <music21.chord.Chord E3 A3>
#     {61.5} <music21.chord.Chord E3 A3>
#     {62.0} <music21.chord.Chord F3 A3>
#     {62.5} <music21.chord.Chord F3 A3>
#     {63.0} <music21.chord.Chord F3 A3>
#     {63.5} <music21.chord.Chord F3 A3>
#     {64.0} <music21.chord.Chord E3 A3>
#     {64.5} <music21.chord.Chord E3 A3>
#     {65.0} <music21.chord.Chord E3 A3>
#     {65.5} <music21.chord.Chord E3 A3>
#     {66.0} <music21.chord.Chord F3 A3>
#     {66.5} <music21.chord.Chord F3 A3>
#     {67.0} <music21.chord.Chord F3 A3>
#     {67.5} <music21.chord.Chord F3 A3>
#     {68.0} <music21.chord.Chord E3 A3>
#     {68.5} <music21.chord.Chord E3 A3>
#     {69.0} <music21.chord.Chord E3 A3>
#     {69.5} <music21.chord.Chord E3 A3>
#     {70.0} <music21.chord.Chord F3 A3>
#     {70.5} <music21.chord.Chord F3 A3>
#     {71.0} <music21.chord.Chord F3 A3>
#     {71.5} <music21.chord.Chord F3 A3>
#     {72.0} <music21.chord.Chord E3 A3>
#     {72.5} <music21.chord.Chord E3 A3>
#     {73.0} <music21.chord.Chord E3 A3>
#     {73.5} <music21.chord.Chord E3 A3>
#     {74.0} <music21.chord.Chord F3 A3>
#     {74.5} <music21.chord.Chord F3 A3>
#     {75.0} <music21.chord.Chord F3 A3>
#     {75.5} <music21.chord.Chord F3 A3>
#     {76.0} <music21.chord.Chord E3 A3>
#     {76.5} <music21.chord.Chord E3 A3>
#     {77.0} <music21.chord.Chord E3 A3>
#     {77.5} <music21.chord.Chord E3 A3>
#     {78.0} <music21.chord.Chord F3 A3>
#     {78.5} <music21.chord.Chord F3 A3>
#     {79.0} <music21.chord.Chord F3 A3>
#     {79.5} <music21.chord.Chord F3 A3>
#     {80.0} <music21.chord.Chord E2 E3>
#     {81.75} <music21.note.Rest rest>
#     {82.0} <music21.chord.Chord F2 F3>
#     {83.75} <music21.note.Rest rest>
#     {84.0} <music21.chord.Chord F#2 F#3>
#     {85.75} <music21.note.Rest rest>
#     {86.0} <music21.chord.Chord F2 F3>
#     {87.75} <music21.note.Rest rest>
#     {88.0} <music21.chord.Chord E2 E3>
#     {89.75} <music21.note.Rest rest>
#     {90.0} <music21.chord.Chord F2 F3>
#     {91.75} <music21.note.Rest rest>
#     {92.0} <music21.chord.Chord F#2 F#3>
#     {93.75} <music21.note.Rest rest>
#     {94.0} <music21.chord.Chord F2 F3>
#     {95.75} <music21.note.Rest rest>
#     {96.0} <music21.chord.Chord E2 E3>
#     {97.75} <music21.note.Rest rest>
#     {98.0} <music21.chord.Chord F2 F3>
#     {99.75} <music21.note.Rest rest>
#     {100.0} <music21.chord.Chord F#2 F#3>
#     {101.75} <music21.note.Rest rest>
#     {102.0} <music21.chord.Chord F2 F3>
#     {103.75} <music21.note.Rest rest>
#     {104.0} <music21.note.Note A>
#     {104.75} <music21.note.Rest rest>
#     {105.5} <music21.note.Note A>
#     {106.0} <music21.note.Note A>
#     {106.75} <music21.note.Rest rest>
#     {108.0} <music21.note.Note A>
#     {108.75} <music21.note.Rest rest>
#     {109.5} <music21.note.Note A>
#     {110.0} <music21.note.Note A>
#     {110.75} <music21.note.Rest rest>
#     {112.0} <music21.chord.Chord A2 E3>
#     {112.75} <music21.note.Rest rest>
#     {113.5} <music21.chord.Chord A2 E3>
#     {114.0} <music21.chord.Chord A2 E3>
#     {114.75} <music21.note.Rest rest>
#     {115.0} <music21.chord.Chord A2 E3>
#     {115.5} <music21.chord.Chord A2 E3>
#     {116.0} <music21.chord.Chord B-2 F3>
#     {116.75} <music21.note.Rest rest>
#     {117.5} <music21.chord.Chord B-2 F3>
#     {118.0} <music21.chord.Chord B-2 F3>
#     {118.75} <music21.note.Rest rest>
#     {119.0} <music21.chord.Chord B-2 F3>
#     {119.5} <music21.chord.Chord B-2 F3>
#     {120.0} <music21.chord.Chord A2 E3>
#     {120.75} <music21.note.Rest rest>
#     {121.5} <music21.chord.Chord A2 E3>
#     {122.0} <music21.chord.Chord A2 E3>
#     {122.75} <music21.note.Rest rest>
#     {123.0} <music21.chord.Chord A2 E3>
#     {123.5} <music21.chord.Chord A2 E3>
#     {124.0} <music21.chord.Chord F2 C3>
#     {124.75} <music21.note.Rest rest>
#     {125.5} <music21.chord.Chord F2 C3>
#     {126.0} <music21.chord.Chord F2 C3>
#     {126.75} <music21.note.Rest rest>
#     {127.0} <music21.chord.Chord F2 C3>
#     {127.75} <music21.note.Rest rest>
#     {128.0} <music21.chord.Chord A1 E2>
#     {128.75} <music21.note.Rest rest>
#     {129.0} <music21.chord.Chord A1 E2>
#     {129.5} <music21.chord.Chord A1 E2>
#     {130.0} <music21.chord.Chord A1 E2>
#     {130.75} <music21.note.Rest rest>
#     {131.0} <music21.chord.Chord A1 E2>
#     {131.5} <music21.chord.Chord A1 E2>
#     {132.0} <music21.chord.Chord A1 E2>
#     {132.75} <music21.note.Rest rest>
#     {133.0} <music21.chord.Chord A1 E2>
#     {133.5} <music21.chord.Chord A1 E2>
#     {134.0} <music21.chord.Chord A1 E2>
#     {134.75} <music21.note.Rest rest>
#     {135.0} <music21.chord.Chord A1 E2>
#     {135.5} <music21.chord.Chord A1 E2>
#     {136.0} <music21.chord.Chord A1 E2>
#     {136.75} <music21.note.Rest rest>
#     {137.0} <music21.chord.Chord A1 E2>
#     {137.5} <music21.chord.Chord A1 E2>
#     {138.0} <music21.chord.Chord A1 E2>
#     {138.75} <music21.note.Rest rest>
#     {139.0} <music21.chord.Chord A1 E2>
#     {139.5} <music21.chord.Chord A1 E2>
#     {140.0} <music21.chord.Chord A1 E2>
#     {140.75} <music21.note.Rest rest>
#     {141.0} <music21.chord.Chord A1 E2>
#     {141.5} <music21.chord.Chord A1 E2>
#     {142.0} <music21.chord.Chord A1 E2>
#     {142.75} <music21.note.Rest rest>
#     {143.0} <music21.chord.Chord A1 E2>
#     {143.75} <music21.note.Rest rest>
#     {144.0} <music21.chord.Chord A2 E3>
#     {144.75} <music21.note.Rest rest>
#     {145.5} <music21.chord.Chord A2 E3>
#     {146.0} <music21.chord.Chord A2 E3>
#     {146.75} <music21.note.Rest rest>
#     {147.0} <music21.chord.Chord A2 E3>
#     {147.5} <music21.chord.Chord A2 E3>
#     {148.0} <music21.chord.Chord B-2 F3>
#     {148.75} <music21.note.Rest rest>
#     {149.5} <music21.chord.Chord B-2 F3>
#     {150.0} <music21.chord.Chord B-2 F3>
#     {150.75} <music21.note.Rest rest>
#     {151.0} <music21.chord.Chord B-2 F3>
#     {151.5} <music21.chord.Chord B-2 F3>
#     {152.0} <music21.chord.Chord A2 E3>
#     {152.75} <music21.note.Rest rest>
#     {153.5} <music21.chord.Chord A2 E3>
#     {154.0} <music21.chord.Chord A2 E3>
#     {154.75} <music21.note.Rest rest>
#     {155.0} <music21.chord.Chord A2 E3>
#     {155.5} <music21.chord.Chord A2 E3>
#     {156.0} <music21.chord.Chord F2 C3>
#     {156.75} <music21.note.Rest rest>
#     {157.5} <music21.chord.Chord F2 C3>
#     {158.0} <music21.chord.Chord F2 C3>
#     {158.75} <music21.note.Rest rest>
#     {159.0} <music21.chord.Chord F2 C3>
#     {159.75} <music21.note.Rest rest>
#     {160.0} <music21.chord.Chord A1 E2>
#     {160.75} <music21.note.Rest rest>
#     {161.0} <music21.chord.Chord A1 E2>
#     {161.5} <music21.chord.Chord A1 E2>
#     {162.0} <music21.chord.Chord A1 E2>
#     {162.75} <music21.note.Rest rest>
#     {163.0} <music21.chord.Chord A1 E2>
#     {163.5} <music21.chord.Chord A1 E2>
#     {164.0} <music21.chord.Chord A1 F#2>
#     {164.75} <music21.note.Rest rest>
#     {165.0} <music21.chord.Chord A1 F#2>
#     {165.5} <music21.chord.Chord A1 F#2>
#     {166.0} <music21.chord.Chord A1 F#2>
#     {166.75} <music21.note.Rest rest>
#     {167.0} <music21.chord.Chord A1 F#2>
#     {167.5} <music21.chord.Chord A1 F#2>
#     {168.0} <music21.chord.Chord A1 G2>
#     {168.75} <music21.note.Rest rest>
#     {169.0} <music21.chord.Chord A1 G2>
#     {169.5} <music21.chord.Chord A1 G2>
#     {170.0} <music21.chord.Chord A1 G2>
#     {170.75} <music21.note.Rest rest>
#     {171.0} <music21.chord.Chord A1 G2>
#     {171.5} <music21.chord.Chord A1 G2>
#     {172.0} <music21.chord.Chord A1 A2>
#     {172.75} <music21.note.Rest rest>
#     {173.0} <music21.chord.Chord A1 A2>
#     {173.5} <music21.chord.Chord A1 A2>
#     {174.0} <music21.chord.Chord A1 A2>
#     {174.75} <music21.note.Rest rest>
#     {175.0} <music21.chord.Chord A1 A2>
#     {175.5} <music21.chord.Chord A1 A2>
#     {176.0} <music21.note.Note F>
#     {176.75} <music21.note.Rest rest>
#     {177.5} <music21.note.Note E->
#     {178.0} <music21.note.Note C#>
#     {178.75} <music21.note.Rest rest>
#     {179.5} <music21.note.Note E->
#     {180.0} <music21.note.Note F>
#     {180.75} <music21.note.Rest rest>
#     {181.5} <music21.note.Note G>
#     {182.0} <music21.note.Note G#>
#     {182.75} <music21.note.Rest rest>
#     {183.0} <music21.note.Note B->
#     {183.75} <music21.note.Rest rest>
#     {184.0} <music21.note.Note B>
#     {184.75} <music21.note.Rest rest>
#     {185.5} <music21.note.Note A>
#     {186.0} <music21.note.Note G>
#     {186.75} <music21.note.Rest rest>
#     {187.5} <music21.note.Note A>
#     {188.0} <music21.note.Note B>
#     {188.75} <music21.note.Rest rest>
#     {189.5} <music21.note.Note C#>
#     {190.0} <music21.note.Note D>
#     {190.75} <music21.note.Rest rest>
#     {191.0} <music21.note.Note C#>
#     {191.75} <music21.note.Rest rest>
#     {192.0} <music21.chord.Chord C3 G3>
#     {192.75} <music21.note.Rest rest>
#     {193.5} <music21.note.Note G>
#     {194.0} <music21.chord.Chord C3 G3>
#     {194.75} <music21.note.Rest rest>
#     {195.5} <music21.note.Note G>
#     {196.0} <music21.chord.Chord C3 G3>
#     {196.75} <music21.note.Rest rest>
#     {197.5} <music21.note.Note G>
#     {198.0} <music21.chord.Chord C3 G3>
#     {198.75} <music21.note.Rest rest>
#     {199.5} <music21.note.Note G>
#     {200.0} <music21.chord.Chord C3 G3>
#     {200.75} <music21.note.Rest rest>
#     {201.5} <music21.note.Note G>
#     {202.0} <music21.chord.Chord C3 G3>
#     {202.75} <music21.note.Rest rest>
#     {203.5} <music21.note.Note G>
#     {204.0} <music21.chord.Chord C3 G3>
#     {204.75} <music21.note.Rest rest>
#     {205.5} <music21.note.Note G>
#     {206.0} <music21.chord.Chord C3 G3>
#     {206.75} <music21.note.Rest rest>
#     {207.5} <music21.note.Note C#>
#     {208.0} <music21.chord.Chord D3 A3>
#     {208.75} <music21.note.Rest rest>
#     {209.5} <music21.note.Note A>
#     {210.0} <music21.chord.Chord D3 A3>
#     {210.75} <music21.note.Rest rest>
#     {211.5} <music21.note.Note A>
#     {212.0} <music21.chord.Chord D3 A3>
#     {212.75} <music21.note.Rest rest>
#     {213.5} <music21.note.Note A>
#     {214.0} <music21.chord.Chord D3 A3>
#     {214.75} <music21.note.Rest rest>
#     {215.5} <music21.note.Note A>
#     {216.0} <music21.chord.Chord D3 A3>
#     {216.75} <music21.note.Rest rest>
#     {217.5} <music21.note.Note A>
#     {218.0} <music21.chord.Chord D3 A3>
#     {218.75} <music21.note.Rest rest>
#     {219.5} <music21.note.Note A>
#     {220.0} <music21.meter.TimeSignature 2/4>
#     {220.0} <music21.note.Note E->
#     {221.75} <music21.note.Rest rest>
#     {222.0} <music21.meter.TimeSignature 4/4>
#     {222.0} <music21.note.Note E>
#     {222.5} <music21.note.Note A>
#     {223.0} <music21.note.Note F>
#     {223.5} <music21.note.Note B->
#     {224.0} <music21.note.Note E>
#     {224.5} <music21.note.Note A>
#     {225.0} <music21.note.Note F>
#     {225.5} <music21.note.Note B->
#     {226.0} <music21.chord.Chord E3 A3>
#     {226.75} <music21.note.Rest rest>
#     {227.0} <music21.note.Note F>
#     {227.75} <music21.note.Rest rest>
#     {228.0} <music21.note.Note F#>
#     {228.75} <music21.note.Rest rest>
#     {229.0} <music21.note.Note G>
#     {229.75} <music21.note.Rest rest>
#     {230.0} <music21.note.Note G#>
#     {233.75} <music21.note.Rest rest>
#     {234.0} <music21.chord.Chord E2 B-2>
#     {234.75} <music21.note.Rest rest>
#     {235.0} <music21.chord.Chord E2 B-2>
#     {235.75} <music21.note.Rest rest>
#     {236.0} <music21.chord.Chord E2 B-2>
#     {236.5} <music21.chord.Chord E2 B-2>
#     {237.0} <music21.chord.Chord E2 B-2>
#     {237.5} <music21.chord.Chord E2 B-2>
#     {238.0} <music21.chord.Chord A1 E2>
#     {238.75} <music21.note.Rest rest>
#     {239.0} <music21.chord.Chord A1 E2>
#     {239.5} <music21.chord.Chord A1 E2>
#     {240.0} <music21.chord.Chord A1 E2>
#     {240.75} <music21.note.Rest rest>
#     {241.0} <music21.chord.Chord A1 E2>
#     {241.5} <music21.chord.Chord A1 E2>
#     {242.0} <music21.chord.Chord A1 E2>
#     {242.75} <music21.note.Rest rest>
#     {243.0} <music21.chord.Chord A1 E2>
#     {243.5} <music21.chord.Chord A1 E2>
#     {244.0} <music21.chord.Chord A1 E2>
#     {244.75} <music21.note.Rest rest>
#     {245.0} <music21.chord.Chord A1 E2>
#     {245.5} <music21.chord.Chord A1 E2>
#     {246.0} <music21.chord.Chord A1 E2>
#     {246.75} <music21.note.Rest rest>
#     {247.0} <music21.chord.Chord A1 E2>
#     {247.5} <music21.chord.Chord A1 E2>
#     {248.0} <music21.chord.Chord A1 E2>
#     {248.75} <music21.note.Rest rest>
#     {249.0} <music21.chord.Chord A1 E2>
#     {249.5} <music21.chord.Chord A1 E2>
#     {250.0} <music21.chord.Chord A1 E2>
#     {250.75} <music21.note.Rest rest>
#     {251.0} <music21.chord.Chord A1 E2>
#     {251.5} <music21.chord.Chord A1 E2>
#     {252.0} <music21.chord.Chord A1 E2>
#     {252.75} <music21.note.Rest rest>
#     {253.0} <music21.chord.Chord A1 E2>
#     {253.5} <music21.chord.Chord A1 E2>
#     {254.0} <music21.chord.Chord A1 E2>
#     {254.75} <music21.note.Rest rest>
#     {255.0} <music21.chord.Chord A1 E2>
#     {255.5} <music21.chord.Chord A1 E2>
#     {256.0} <music21.chord.Chord A1 E2>
#     {256.75} <music21.note.Rest rest>
#     {257.0} <music21.chord.Chord A1 E2>
#     {257.5} <music21.chord.Chord A1 E2>
#     {258.0} <music21.chord.Chord A1 E2>
#     {258.75} <music21.note.Rest rest>
#     {259.0} <music21.chord.Chord A1 E2>
#     {259.5} <music21.chord.Chord A1 E2>
#     {260.0} <music21.chord.Chord A1 E2>
#     {260.75} <music21.note.Rest rest>
#     {261.0} <music21.chord.Chord A1 E2>
#     {261.5} <music21.chord.Chord A1 E2>
#     {262.0} <music21.chord.Chord A1 E2>
#     {262.75} <music21.note.Rest rest>
#     {263.0} <music21.chord.Chord A1 E2>
#     {263.5} <music21.chord.Chord A1 E2>
#     {264.0} <music21.chord.Chord A1 E2>
#     {264.75} <music21.note.Rest rest>
#     {265.0} <music21.chord.Chord A1 E2>
#     {265.5} <music21.chord.Chord A1 E2>
#     {266.0} <music21.chord.Chord A1 E2>
#     {266.75} <music21.note.Rest rest>
#     {267.0} <music21.chord.Chord A1 E2>
#     {267.5} <music21.chord.Chord A1 E2>
#     {268.0} <music21.chord.Chord A1 E2>
#     {268.75} <music21.note.Rest rest>
#     {269.0} <music21.chord.Chord A1 E2>
#     {269.5} <music21.chord.Chord A1 E2>
#     {270.0} <music21.note.Note E->
#     {271.75} <music21.note.Rest rest>
#     {272.0} <music21.note.Note B>
#     {272.75} <music21.note.Rest rest>
#     {273.0} <music21.note.Note G>
#     {273.75} <music21.note.Rest rest>
#     {274.0} <music21.note.Note F#>
#     {277.75} <music21.note.Rest rest>
#     {278.0} <music21.note.Note E->
#     {280.5} <music21.note.Note G>
#     {281.0} <music21.note.Note B>
#     {281.5} <music21.note.Note E->
#     {282.0} <music21.note.Note G#>
#     {282.75} <music21.note.Rest rest>
#     {283.0} <music21.note.Note F>
#     {285.75} <music21.note.Rest rest>
#     {286.0} <music21.note.Note F>
#     {286.75} <music21.note.Rest rest>
#     {287.0} <music21.note.Note F>
#     {287.75} <music21.note.Rest rest>
#     {288.0} <music21.note.Note F>
#     {288.5} <music21.note.Note F>
#     {289.0} <music21.note.Note F>
#     {289.75} <music21.note.Rest rest>
#     {290.0} <music21.chord.Chord E3 A3>
#     {290.5} <music21.chord.Chord E3 A3>
#     {291.0} <music21.chord.Chord E3 A3>
#     {291.5} <music21.chord.Chord E3 A3>
#     {292.0} <music21.chord.Chord F3 A3>
#     {292.5} <music21.chord.Chord F3 A3>
#     {293.0} <music21.chord.Chord F3 A3>
#     {293.5} <music21.chord.Chord F3 A3>
#     {294.0} <music21.chord.Chord E3 A3>
#     {294.5} <music21.chord.Chord E3 A3>
#     {295.0} <music21.chord.Chord E3 A3>
#     {295.5} <music21.chord.Chord E3 A3>
#     {296.0} <music21.chord.Chord F3 A3>
#     {296.5} <music21.chord.Chord F3 A3>
#     {297.0} <music21.chord.Chord F3 A3>
#     {297.5} <music21.chord.Chord F3 A3>
#     {298.0} <music21.chord.Chord E3 A3>
#     {298.5} <music21.chord.Chord E3 A3>
#     {299.0} <music21.chord.Chord E3 A3>
#     {299.5} <music21.chord.Chord E3 A3>
#     {300.0} <music21.chord.Chord F3 A3>
#     {300.5} <music21.chord.Chord F3 A3>
#     {301.0} <music21.chord.Chord F3 A3>
#     {301.5} <music21.chord.Chord F3 A3>
#     {302.0} <music21.chord.Chord E3 A3>
#     {302.5} <music21.chord.Chord E3 A3>
#     {303.0} <music21.chord.Chord E3 A3>
#     {303.5} <music21.chord.Chord E3 A3>
#     {304.0} <music21.chord.Chord F3 A3>
#     {304.5} <music21.chord.Chord F3 A3>
#     {305.0} <music21.chord.Chord F3 A3>
#     {305.5} <music21.chord.Chord F3 A3>
#     {306.0} <music21.chord.Chord E3 A3>
#     {306.5} <music21.chord.Chord E3 A3>
#     {307.0} <music21.chord.Chord E3 A3>
#     {307.5} <music21.chord.Chord E3 A3>
#     {308.0} <music21.chord.Chord F3 A3>
#     {308.5} <music21.chord.Chord F3 A3>
#     {309.0} <music21.chord.Chord F3 A3>
#     {309.5} <music21.chord.Chord F3 A3>
#     {310.0} <music21.chord.Chord E3 A3>
#     {310.5} <music21.chord.Chord E3 A3>
#     {311.0} <music21.chord.Chord E3 A3>
#     {311.5} <music21.chord.Chord E3 A3>
#     {312.0} <music21.chord.Chord F3 A3>
#     {312.5} <music21.chord.Chord F3 A3>
#     {313.0} <music21.chord.Chord F3 A3>
#     {313.5} <music21.chord.Chord F3 A3>
#     {314.0} <music21.chord.Chord E2 E3>
#     {315.75} <music21.note.Rest rest>
#     {316.0} <music21.chord.Chord F2 F3>
#     {317.75} <music21.note.Rest rest>
#     {318.0} <music21.chord.Chord F#2 F#3>
#     {319.75} <music21.note.Rest rest>
#     {320.0} <music21.chord.Chord F2 F3>
#     {321.75} <music21.note.Rest rest>
#     {322.0} <music21.chord.Chord E2 E3>
#     {323.75} <music21.note.Rest rest>
#     {324.0} <music21.chord.Chord F2 F3>
#     {325.75} <music21.note.Rest rest>
#     {326.0} <music21.chord.Chord F#2 F#3>
#     {327.75} <music21.note.Rest rest>
#     {328.0} <music21.chord.Chord F2 F3>
#     {329.75} <music21.note.Rest rest>
#     {330.0} <music21.chord.Chord E2 E3>
#     {331.75} <music21.note.Rest rest>
#     {332.0} <music21.chord.Chord F2 F3>
#     {333.75} <music21.note.Rest rest>
#     {334.0} <music21.chord.Chord F#2 F#3>
#     {335.75} <music21.note.Rest rest>
#     {336.0} <music21.chord.Chord F2 F3>
#     {337.75} <music21.note.Rest rest>
#     {338.0} <music21.note.Note A>
#     {338.75} <music21.note.Rest rest>
#     {339.5} <music21.note.Note A>
#     {340.0} <music21.note.Note A>
#     {340.75} <music21.note.Rest rest>
#     {342.0} <music21.note.Note A>
#     {342.75} <music21.note.Rest rest>
#     {343.5} <music21.note.Note A>
#     {344.0} <music21.note.Note A>
#     {344.75} <music21.note.Rest rest>
#     {346.0} <music21.chord.Chord A2 E3>
#     {346.75} <music21.note.Rest rest>
#     {347.5} <music21.chord.Chord A2 E3>
#     {348.0} <music21.chord.Chord A2 E3>
#     {348.75} <music21.note.Rest rest>
#     {349.0} <music21.chord.Chord A2 E3>
#     {349.5} <music21.chord.Chord A2 E3>
#     {350.0} <music21.chord.Chord B-2 F3>
#     {350.75} <music21.note.Rest rest>
#     {351.5} <music21.chord.Chord B-2 F3>
#     {352.0} <music21.chord.Chord B-2 F3>
#     {352.75} <music21.note.Rest rest>
#     {353.0} <music21.chord.Chord B-2 F3>
#     {353.5} <music21.chord.Chord B-2 F3>
#     {354.0} <music21.chord.Chord A2 E3>
#     {354.75} <music21.note.Rest rest>
#     {355.5} <music21.chord.Chord A2 E3>
#     {356.0} <music21.chord.Chord A2 E3>
#     {356.75} <music21.note.Rest rest>
#     {357.0} <music21.chord.Chord A2 E3>
#     {357.5} <music21.chord.Chord A2 E3>
#     {358.0} <music21.chord.Chord F2 C3>
#     {358.75} <music21.note.Rest rest>
#     {359.5} <music21.chord.Chord F2 C3>
#     {360.0} <music21.chord.Chord F2 C3>
#     {360.75} <music21.note.Rest rest>
#     {361.0} <music21.chord.Chord F2 C3>
#     {361.75} <music21.note.Rest rest>
#     {362.0} <music21.chord.Chord A1 E2>
#     {362.75} <music21.note.Rest rest>
#     {363.0} <music21.chord.Chord A1 E2>
#     {363.5} <music21.chord.Chord A1 E2>
#     {364.0} <music21.chord.Chord A1 E2>
#     {364.75} <music21.note.Rest rest>
#     {365.0} <music21.chord.Chord A1 E2>
#     {365.5} <music21.chord.Chord A1 E2>
#     {366.0} <music21.chord.Chord A1 E2>
#     {366.75} <music21.note.Rest rest>
#     {367.0} <music21.chord.Chord A1 E2>
#     {367.5} <music21.chord.Chord A1 E2>
#     {368.0} <music21.chord.Chord A1 E2>
#     {368.75} <music21.note.Rest rest>
#     {369.0} <music21.chord.Chord A1 E2>
#     {369.5} <music21.chord.Chord A1 E2>
#     {370.0} <music21.chord.Chord A1 E2>
#     {370.75} <music21.note.Rest rest>
#     {371.0} <music21.chord.Chord A1 E2>
#     {371.5} <music21.chord.Chord A1 E2>
#     {372.0} <music21.chord.Chord A1 E2>
#     {372.75} <music21.note.Rest rest>
#     {373.0} <music21.chord.Chord A1 E2>
#     {373.5} <music21.chord.Chord A1 E2>
#     {374.0} <music21.chord.Chord A1 E2>
#     {374.75} <music21.note.Rest rest>
#     {375.0} <music21.chord.Chord A1 E2>
#     {375.5} <music21.chord.Chord A1 E2>
#     {376.0} <music21.chord.Chord A1 E2>
#     {376.75} <music21.note.Rest rest>
#     {377.0} <music21.chord.Chord A1 E2>
#     {377.75} <music21.note.Rest rest>
#     {378.0} <music21.chord.Chord A2 E3>
#     {378.75} <music21.note.Rest rest>
#     {379.5} <music21.chord.Chord A2 E3>
#     {380.0} <music21.chord.Chord A2 E3>
#     {380.75} <music21.note.Rest rest>
#     {381.0} <music21.chord.Chord A2 E3>
#     {381.5} <music21.chord.Chord A2 E3>
#     {382.0} <music21.chord.Chord B-2 F3>
#     {382.75} <music21.note.Rest rest>
#     {383.5} <music21.chord.Chord B-2 F3>
#     {384.0} <music21.chord.Chord B-2 F3>
#     {384.75} <music21.note.Rest rest>
#     {385.0} <music21.chord.Chord B-2 F3>
#     {385.5} <music21.chord.Chord B-2 F3>
#     {386.0} <music21.chord.Chord A2 E3>
#     {386.75} <music21.note.Rest rest>
#     {387.5} <music21.chord.Chord A2 E3>
#     {388.0} <music21.chord.Chord A2 E3>
#     {388.75} <music21.note.Rest rest>
#     {389.0} <music21.chord.Chord A2 E3>
#     {389.5} <music21.chord.Chord A2 E3>
#     {390.0} <music21.chord.Chord F2 C3>
#     {390.75} <music21.note.Rest rest>
#     {391.5} <music21.chord.Chord F2 C3>
#     {392.0} <music21.chord.Chord F2 C3>
#     {392.75} <music21.note.Rest rest>
#     {393.0} <music21.chord.Chord F2 C3>
#     {393.75} <music21.note.Rest rest>
#     {394.0} <music21.chord.Chord A1 E2>
#     {394.75} <music21.note.Rest rest>
#     {395.0} <music21.chord.Chord A1 E2>
#     {395.5} <music21.chord.Chord A1 E2>
#     {396.0} <music21.chord.Chord A1 E2>
#     {396.75} <music21.note.Rest rest>
#     {397.0} <music21.chord.Chord A1 E2>
#     {397.5} <music21.chord.Chord A1 E2>
#     {398.0} <music21.chord.Chord A1 F#2>
#     {398.75} <music21.note.Rest rest>
#     {399.0} <music21.chord.Chord A1 F#2>
#     {399.5} <music21.chord.Chord A1 F#2>
#     {400.0} <music21.chord.Chord A1 F#2>
#     {400.75} <music21.note.Rest rest>
#     {401.0} <music21.chord.Chord A1 F#2>
#     {401.5} <music21.chord.Chord A1 F#2>
#     {402.0} <music21.chord.Chord A1 G2>
#     {402.75} <music21.note.Rest rest>
#     {403.0} <music21.chord.Chord A1 G2>
#     {403.5} <music21.chord.Chord A1 G2>
#     {404.0} <music21.chord.Chord A1 G2>
#     {404.75} <music21.note.Rest rest>
#     {405.0} <music21.chord.Chord A1 G2>
#     {405.5} <music21.chord.Chord A1 G2>
#     {406.0} <music21.chord.Chord A1 A2>
#     {406.75} <music21.note.Rest rest>
#     {407.0} <music21.chord.Chord A1 A2>
#     {407.5} <music21.chord.Chord A1 A2>
#     {408.0} <music21.chord.Chord A1 A2>
#     {408.75} <music21.note.Rest rest>
#     {409.0} <music21.chord.Chord A1 A2>
#     {409.5} <music21.chord.Chord A1 A2>
#     {410.0} <music21.note.Note F>
#     {410.75} <music21.note.Rest rest>
#     {411.5} <music21.note.Note E->
#     {412.0} <music21.note.Note C#>
#     {412.75} <music21.note.Rest rest>
#     {413.5} <music21.note.Note E->
#     {414.0} <music21.note.Note F>
#     {414.75} <music21.note.Rest rest>
#     {415.5} <music21.note.Note G>
#     {416.0} <music21.note.Note G#>
#     {416.75} <music21.note.Rest rest>
#     {417.0} <music21.note.Note B->
#     {417.75} <music21.note.Rest rest>
#     {418.0} <music21.note.Note B>
#     {418.75} <music21.note.Rest rest>
#     {419.5} <music21.note.Note A>
#     {420.0} <music21.note.Note G>
#     {420.75} <music21.note.Rest rest>
#     {421.5} <music21.note.Note A>
#     {422.0} <music21.note.Note B>
#     {422.75} <music21.note.Rest rest>
#     {423.5} <music21.note.Note C#>
#     {424.0} <music21.note.Note D>
#     {424.75} <music21.note.Rest rest>
#     {425.0} <music21.note.Note C#>
#     {425.75} <music21.note.Rest rest>
#     {426.0} <music21.chord.Chord C3 G3>
#     {426.75} <music21.note.Rest rest>
#     {427.5} <music21.note.Note G>
#     {428.0} <music21.chord.Chord C3 G3>
#     {428.75} <music21.note.Rest rest>
#     {429.5} <music21.note.Note G>
#     {430.0} <music21.chord.Chord C3 G3>
#     {430.75} <music21.note.Rest rest>
#     {431.5} <music21.note.Note G>
#     {432.0} <music21.chord.Chord C3 G3>
#     {432.75} <music21.note.Rest rest>
#     {433.5} <music21.note.Note G>
#     {434.0} <music21.chord.Chord C3 G3>
#     {434.75} <music21.note.Rest rest>
#     {435.5} <music21.note.Note G>
#     {436.0} <music21.chord.Chord C3 G3>
#     {436.75} <music21.note.Rest rest>
#     {437.5} <music21.note.Note G>
#     {438.0} <music21.chord.Chord C3 G3>
#     {438.75} <music21.note.Rest rest>
#     {439.5} <music21.note.Note G>
#     {440.0} <music21.chord.Chord C3 G3>
#     {440.75} <music21.note.Rest rest>
#     {441.5} <music21.note.Note C#>
#     {442.0} <music21.chord.Chord D3 A3>
#     {442.75} <music21.note.Rest rest>
#     {443.5} <music21.note.Note A>
#     {444.0} <music21.chord.Chord D3 A3>
#     {444.75} <music21.note.Rest rest>
#     {445.5} <music21.note.Note A>
#     {446.0} <music21.chord.Chord D3 A3>
#     {446.75} <music21.note.Rest rest>
#     {447.5} <music21.note.Note A>
#     {448.0} <music21.chord.Chord D3 A3>
#     {448.75} <music21.note.Rest rest>
#     {449.5} <music21.note.Note A>
#     {450.0} <music21.chord.Chord D3 A3>
#     {450.75} <music21.note.Rest rest>
#     {451.5} <music21.note.Note A>
#     {452.0} <music21.chord.Chord D3 A3>
#     {452.75} <music21.note.Rest rest>
#     {453.5} <music21.note.Note A>
#     {454.0} <music21.meter.TimeSignature 2/4>
#     {454.0} <music21.note.Note E->
#     {455.75} <music21.note.Rest rest>
#     {456.0} <music21.meter.TimeSignature 4/4>
#     {456.0} <music21.note.Note E>
#     {456.5} <music21.note.Note A>
#     {457.0} <music21.note.Note F>
#     {457.5} <music21.note.Note B->
#     {458.0} <music21.note.Note E>
#     {458.5} <music21.note.Note A>
#     {459.0} <music21.note.Note F>
#     {459.5} <music21.note.Note B->
#     {460.0} <music21.chord.Chord E3 A3>
#     {460.75} <music21.note.Rest rest>
#     {461.0} <music21.note.Note F>
#     {461.75} <music21.note.Rest rest>
#     {462.0} <music21.note.Note F#>
#     {462.75} <music21.note.Rest rest>
#     {463.0} <music21.note.Note G>
#     {463.75} <music21.note.Rest rest>
#     {464.0} <music21.note.Note G#>
#     {467.75} <music21.note.Rest rest>
#     {468.0} <music21.chord.Chord E2 B-2>
#     {468.75} <music21.note.Rest rest>
#     {469.0} <music21.chord.Chord E2 B-2>
#     {469.75} <music21.note.Rest rest>
#     {470.0} <music21.chord.Chord E2 B-2>
#     {470.5} <music21.chord.Chord E2 B-2>
#     {471.0} <music21.chord.Chord E2 B-2>
#     {471.5} <music21.chord.Chord E2 B-2>
#     {472.0} <music21.note.Note A>
#     {472.75} <music21.note.Rest rest>
#     {473.0} <music21.chord.Chord A1 E2>

# %%
elements_to_parse = midi.flat.notes

# %%
len(elements_to_parse)
# Out:
# 1171

# %%
for e in elements_to_parse:
    print(e, e.offset)
# Out:
# <music21.chord.Chord E3 A3> 4.0
# <music21.note.Note E> 4.0
# <music21.chord.Chord A1 E2> 4.0
# <music21.chord.Chord E3 A3> 5.0
# <music21.chord.Chord A1 E2> 5.0
# <music21.chord.Chord A1 E2> 5.5
# <music21.chord.Chord A1 E2> 6.0
# <music21.chord.Chord A1 E2> 7.0
# <music21.chord.Chord A1 E2> 7.5
# <music21.chord.Chord E3 B3> 8.0
# <music21.chord.Chord A1 E2> 8.0
# <music21.chord.Chord E3 B3> 9.0
# <music21.chord.Chord A1 E2> 9.0
# <music21.chord.Chord A1 E2> 9.5
# <music21.chord.Chord A1 E2> 10.0
# <music21.chord.Chord A1 E2> 11.0
# <music21.chord.Chord A1 E2> 11.5
# <music21.chord.Chord E3 C4> 12.0
# <music21.note.Note E> 12.0
# <music21.chord.Chord A1 E2> 12.0
# <music21.chord.Chord E3 C4> 13.0
# <music21.chord.Chord A1 E2> 13.0
# <music21.chord.Chord A1 E2> 13.5
# <music21.chord.Chord A1 E2> 14.0
# <music21.chord.Chord A1 E2> 15.0
# <music21.chord.Chord A1 E2> 15.5
# <music21.chord.Chord A3 D4> 16.0
# <music21.chord.Chord A1 E2> 16.0
# <music21.chord.Chord A3 D4> 16.5
# <music21.chord.Chord A3 D4> 17.0
# <music21.chord.Chord A1 E2> 17.0
# <music21.chord.Chord A1 E2> 17.5
# <music21.chord.Chord A1 E2> 18.0
# <music21.chord.Chord A1 E2> 19.0
# <music21.chord.Chord A1 E2> 19.5
# <music21.chord.Chord E4 A4> 20.0
# <music21.note.Note E> 20.0
# <music21.chord.Chord A1 E2> 20.0
# <music21.chord.Chord E4 A4> 21.0
# <music21.chord.Chord A1 E2> 21.0
# <music21.chord.Chord A1 E2> 21.5
# <music21.chord.Chord A1 E2> 22.0
# <music21.note.Note E> 22.5
# <music21.note.Note F> 22.75
# <music21.note.Note G#> 22.75
# <music21.note.Note A> 23.0
# <music21.chord.Chord A1 E2> 23.0
# <music21.chord.Chord A1 E2> 23.5
# <music21.chord.Chord F4 B4> 24.0
# <music21.chord.Chord A1 E2> 24.0
# <music21.chord.Chord F4 B4> 25.0
# <music21.chord.Chord A1 E2> 25.0
# <music21.chord.Chord A1 E2> 25.5
# <music21.chord.Chord A1 E2> 26.0
# <music21.note.Note E> 26.5
# <music21.note.Note F> 26.75
# <music21.note.Note G#> 26.75
# <music21.note.Note A> 27.0
# <music21.chord.Chord A1 E2> 27.0
# <music21.chord.Chord A1 E2> 27.5
# <music21.chord.Chord A4 C5> 28.0
# <music21.note.Note E> 28.0
# <music21.chord.Chord A1 E2> 28.0
# <music21.chord.Chord A4 C5> 29.0
# <music21.chord.Chord A1 E2> 29.0
# <music21.chord.Chord A1 E2> 29.5
# <music21.chord.Chord A1 E2> 30.0
# <music21.note.Note E> 30.5
# <music21.note.Note F> 30.75
# <music21.note.Note G#> 30.75
# <music21.note.Note A> 31.0
# <music21.chord.Chord A1 E2> 31.0
# <music21.chord.Chord A1 E2> 31.5
# <music21.chord.Chord B4 D5> 32.0
# <music21.chord.Chord A1 E2> 32.0
# <music21.chord.Chord B4 D5> 32.5
# <music21.chord.Chord B4 D5> 33.0
# <music21.chord.Chord A1 E2> 33.0
# <music21.chord.Chord A1 E2> 33.5
# <music21.chord.Chord A1 E2> 34.0
# <music21.note.Note E> 34.5
# <music21.note.Note F> 34.75
# <music21.note.Note G#> 34.75
# <music21.note.Note A> 35.0
# <music21.chord.Chord A1 E2> 35.0
# <music21.chord.Chord A1 E2> 35.5
# <music21.chord.Chord G4 B4 E-5> 36.0
# <music21.note.Note E-> 36.0
# <music21.chord.Chord G4 B4 E-5> 37.0
# <music21.note.Note B> 38.0
# <music21.note.Note G> 39.0
# <music21.chord.Chord A4 C#5 F5> 40.0
# <music21.note.Note F#> 40.0
# <music21.chord.Chord A4 C#5 F5> 41.0
# <music21.chord.Chord G4 B4 E-5> 44.0
# <music21.note.Note E-> 44.0
# <music21.chord.Chord G4 B4 E-5> 45.0
# <music21.note.Note G> 46.5
# <music21.note.Note B> 47.0
# <music21.note.Note E-> 47.5
# <music21.chord.Chord A4 C#5 F5> 48.0
# <music21.note.Note G#> 48.0
# <music21.chord.Chord A4 C#5 F5> 48.5
# <music21.chord.Chord A4 C#5 F5> 49.0
# <music21.note.Note F> 49.0
# <music21.note.Note F> 52.0
# <music21.note.Note F> 53.0
# <music21.note.Note F> 54.0
# <music21.note.Note F> 54.5
# <music21.note.Note F> 55.0
# <music21.chord.Chord E3 A3> 56.0
# <music21.note.Note E> 56.5
# <music21.chord.Chord E3 A3> 56.5
# <music21.note.Note C> 57.0
# <music21.chord.Chord E3 A3> 57.0
# <music21.note.Note A> 57.5
# <music21.chord.Chord E3 A3> 57.5
# <music21.chord.Chord F3 A3> 58.0
# <music21.note.Note F> 58.5
# <music21.chord.Chord F3 A3> 58.5
# <music21.note.Note C> 59.0
# <music21.chord.Chord F3 A3> 59.0
# <music21.note.Note A> 59.5
# <music21.chord.Chord F3 A3> 59.5
# <music21.chord.Chord E3 A3> 60.0
# <music21.note.Note E> 60.5
# <music21.chord.Chord E3 A3> 60.5
# <music21.note.Note C> 61.0
# <music21.chord.Chord E3 A3> 61.0
# <music21.note.Note A> 61.5
# <music21.chord.Chord E3 A3> 61.5
# <music21.note.Note F> 62.0
# <music21.chord.Chord F3 A3> 62.0
# <music21.note.Note C> 62.5
# <music21.chord.Chord F3 A3> 62.5
# <music21.note.Note E> 63.0
# <music21.chord.Chord F3 A3> 63.0
# <music21.note.Note D> 63.5
# <music21.chord.Chord F3 A3> 63.5
# <music21.note.Note E> 64.0
# <music21.chord.Chord E3 A3> 64.0
# <music21.note.Note E-> 64.5
# <music21.chord.Chord E3 A3> 64.5
# <music21.note.Note B> 65.0
# <music21.chord.Chord E3 A3> 65.0
# <music21.chord.Chord E3 A3> 65.5
# <music21.note.Note A> 66.0
# <music21.chord.Chord F3 A3> 66.0
# <music21.chord.Chord F3 A3> 66.5
# <music21.chord.Chord F3 A3> 67.0
# <music21.chord.Chord F3 A3> 67.5
# <music21.chord.Chord E3 A3> 68.0
# <music21.chord.Chord E3 A3> 68.5
# <music21.chord.Chord E3 A3> 69.0
# <music21.chord.Chord E3 A3> 69.5
# <music21.chord.Chord F3 A3> 70.0
# <music21.chord.Chord F3 A3> 70.5
# <music21.chord.Chord F3 A3> 71.0
# <music21.chord.Chord F3 A3> 71.5
# <music21.note.Note B> 72.0
# <music21.chord.Chord E3 A3> 72.0
# <music21.note.Note A> 72.5
# <music21.chord.Chord E3 A3> 72.5
# <music21.note.Note E> 73.0
# <music21.chord.Chord E3 A3> 73.0
# <music21.chord.Chord E3 A3> 73.5
# <music21.note.Note E-> 74.0
# <music21.chord.Chord F3 A3> 74.0
# <music21.chord.Chord F3 A3> 74.5
# <music21.chord.Chord F3 A3> 75.0
# <music21.chord.Chord F3 A3> 75.5
# <music21.chord.Chord E3 A3> 76.0
# <music21.chord.Chord E3 A3> 76.5
# <music21.chord.Chord E3 A3> 77.0
# <music21.chord.Chord E3 A3> 77.5
# <music21.chord.Chord F3 A3> 78.0
# <music21.chord.Chord F3 A3> 78.5
# <music21.chord.Chord F3 A3> 79.0
# <music21.chord.Chord F3 A3> 79.5
# <music21.note.Note E> 80.0
# <music21.chord.Chord E2 E3> 80.0
# <music21.note.Note E-> 80.5
# <music21.note.Note C> 81.0
# <music21.note.Note E> 82.0
# <music21.chord.Chord F2 F3> 82.0
# <music21.note.Note E-> 82.5
# <music21.note.Note B> 83.0
# <music21.note.Note E> 84.0
# <music21.chord.Chord F#2 F#3> 84.0
# <music21.note.Note E-> 84.5
# <music21.note.Note C> 85.0
# <music21.note.Note A> 86.0
# <music21.chord.Chord F2 F3> 86.0
# <music21.note.Note A> 88.0
# <music21.chord.Chord E2 E3> 88.0
# <music21.note.Note C> 88.5
# <music21.note.Note E> 89.0
# <music21.note.Note F> 89.5
# <music21.note.Note E> 90.0
# <music21.chord.Chord F2 F3> 90.0
# <music21.note.Note C> 90.5
# <music21.note.Note A> 91.0
# <music21.note.Note C> 91.5
# <music21.note.Note A> 92.0
# <music21.chord.Chord F#2 F#3> 92.0
# <music21.note.Note C> 92.5
# <music21.note.Note E> 93.0
# <music21.note.Note F#> 93.5
# <music21.note.Note E> 94.0
# <music21.chord.Chord F2 F3> 94.0
# <music21.note.Note C> 94.5
# <music21.note.Note A> 95.0
# <music21.note.Note C> 95.5
# <music21.note.Note A> 96.0
# <music21.chord.Chord E2 E3> 96.0
# <music21.note.Note C> 96.5
# <music21.note.Note E> 97.0
# <music21.note.Note F> 97.5
# <music21.note.Note E> 98.0
# <music21.chord.Chord F2 F3> 98.0
# <music21.note.Note C> 98.5
# <music21.note.Note A> 99.0
# <music21.note.Note C> 99.5
# <music21.note.Note A> 100.0
# <music21.chord.Chord F#2 F#3> 100.0
# <music21.note.Note C> 100.5
# <music21.note.Note E> 101.0
# <music21.note.Note F#> 101.5
# <music21.note.Note E> 102.0
# <music21.chord.Chord F2 F3> 102.0
# <music21.note.Note C> 102.5
# <music21.note.Note A> 103.0
# <music21.note.Note C> 103.5
# <music21.note.Note A> 104.0
# <music21.note.Note A> 104.0
# <music21.note.Note C> 104.5
# <music21.note.Note E> 105.0
# <music21.note.Note F> 105.5
# <music21.note.Note A> 105.5
# <music21.note.Note E> 106.0
# <music21.note.Note A> 106.0
# <music21.note.Note C> 106.5
# <music21.note.Note B> 107.0
# <music21.note.Note C> 107.5
# <music21.note.Note A> 108.0
# <music21.note.Note A> 108.0
# <music21.note.Note F> 108.5
# <music21.note.Note E> 109.0
# <music21.note.Note F> 109.5
# <music21.note.Note A> 109.5
# <music21.note.Note E> 110.0
# <music21.note.Note A> 110.0
# <music21.note.Note C> 110.5
# <music21.note.Note B> 111.0
# <music21.note.Note C> 111.5
# <music21.note.Note E> 112.0
# <music21.chord.Chord A2 E3> 112.0
# <music21.note.Note B> 113.0
# <music21.chord.Chord A2 E3> 113.5
# <music21.note.Note A> 114.0
# <music21.chord.Chord A2 E3> 114.0
# <music21.note.Note G> 114.5
# <music21.note.Note F> 115.0
# <music21.chord.Chord A2 E3> 115.0
# <music21.chord.Chord A2 E3> 115.5
# <music21.note.Note E> 116.0
# <music21.chord.Chord B-2 F3> 116.0
# <music21.note.Note F> 116.5
# <music21.note.Note G> 117.0
# <music21.note.Note D> 117.5
# <music21.chord.Chord B-2 F3> 117.5
# <music21.note.Note F> 118.0
# <music21.chord.Chord B-2 F3> 118.0
# <music21.note.Note E> 119.0
# <music21.chord.Chord B-2 F3> 119.0
# <music21.note.Note D> 119.5
# <music21.chord.Chord B-2 F3> 119.5
# <music21.note.Note E> 120.0
# <music21.chord.Chord A2 E3> 120.0
# <music21.note.Note B> 121.0
# <music21.note.Note C> 121.5
# <music21.chord.Chord A2 E3> 121.5
# <music21.note.Note D> 122.0
# <music21.chord.Chord A2 E3> 122.0
# <music21.note.Note C> 123.0
# <music21.chord.Chord A2 E3> 123.0
# <music21.note.Note B> 123.5
# <music21.chord.Chord A2 E3> 123.5
# <music21.note.Note C> 124.0
# <music21.chord.Chord F2 C3> 124.0
# <music21.note.Note B> 124.5
# <music21.note.Note C> 125.0
# <music21.note.Note A> 125.5
# <music21.chord.Chord F2 C3> 125.5
# <music21.note.Note F> 126.0
# <music21.chord.Chord F2 C3> 126.0
# <music21.note.Note G> 127.0
# <music21.chord.Chord F2 C3> 127.0
# <music21.chord.Chord E4 A4> 128.0
# <music21.chord.Chord A1 E2> 128.0
# <music21.chord.Chord E4 A4> 129.0
# <music21.chord.Chord A1 E2> 129.0
# <music21.chord.Chord A1 E2> 129.5
# <music21.note.Note G> 130.0
# <music21.chord.Chord A1 E2> 130.0
# <music21.note.Note F#> 130.5
# <music21.note.Note E> 131.0
# <music21.chord.Chord A1 E2> 131.0
# <music21.chord.Chord A1 E2> 131.5
# <music21.chord.Chord A4 B4> 132.0
# <music21.chord.Chord A1 E2> 132.0
# <music21.chord.Chord A4 B4> 133.0
# <music21.chord.Chord A1 E2> 133.0
# <music21.chord.Chord A1 E2> 133.5
# <music21.note.Note E-> 134.0
# <music21.note.Note D> 134.0
# <music21.chord.Chord A1 E2> 134.0
# <music21.note.Note C> 134.5
# <music21.note.Note D> 135.0
# <music21.chord.Chord A1 E2> 135.0
# <music21.note.Note E> 135.5
# <music21.chord.Chord A1 E2> 135.5
# <music21.chord.Chord A4 C5> 136.0
# <music21.chord.Chord A1 E2> 136.0
# <music21.chord.Chord A4 C5> 137.0
# <music21.chord.Chord A1 E2> 137.0
# <music21.chord.Chord A1 E2> 137.5
# <music21.note.Note C> 138.0
# <music21.chord.Chord A1 E2> 138.0
# <music21.note.Note G#> 138.5
# <music21.note.Note A> 139.0
# <music21.chord.Chord A1 E2> 139.0
# <music21.note.Note C> 139.5
# <music21.chord.Chord A1 E2> 139.5
# <music21.chord.Chord B4 D5> 140.0
# <music21.chord.Chord A1 E2> 140.0
# <music21.chord.Chord B4 D5> 140.5
# <music21.chord.Chord B4 D5> 141.0
# <music21.chord.Chord A1 E2> 141.0
# <music21.chord.Chord A1 E2> 141.5
# <music21.note.Note C> 142.0
# <music21.chord.Chord A1 E2> 142.0
# <music21.note.Note G> 142.25
# <music21.note.Note G#> 142.5
# <music21.note.Note B> 142.75
# <music21.note.Note A> 143.0
# <music21.chord.Chord A1 E2> 143.0
# <music21.note.Note E> 144.0
# <music21.chord.Chord A2 E3> 144.0
# <music21.note.Note B> 145.0
# <music21.chord.Chord A2 E3> 145.5
# <music21.note.Note A> 146.0
# <music21.chord.Chord A2 E3> 146.0
# <music21.note.Note G> 146.5
# <music21.note.Note F> 147.0
# <music21.chord.Chord A2 E3> 147.0
# <music21.chord.Chord A2 E3> 147.5
# <music21.note.Note E> 148.0
# <music21.chord.Chord B-2 F3> 148.0
# <music21.note.Note F> 148.5
# <music21.note.Note G> 149.0
# <music21.note.Note D> 149.5
# <music21.chord.Chord B-2 F3> 149.5
# <music21.note.Note F> 150.0
# <music21.chord.Chord B-2 F3> 150.0
# <music21.note.Note E> 151.0
# <music21.chord.Chord B-2 F3> 151.0
# <music21.note.Note D> 151.5
# <music21.chord.Chord B-2 F3> 151.5
# <music21.note.Note E> 152.0
# <music21.chord.Chord A2 E3> 152.0
# <music21.note.Note B> 153.0
# <music21.note.Note C> 153.5
# <music21.chord.Chord A2 E3> 153.5
# <music21.note.Note D> 154.0
# <music21.chord.Chord A2 E3> 154.0
# <music21.note.Note C> 155.0
# <music21.chord.Chord A2 E3> 155.0
# <music21.note.Note B> 155.5
# <music21.chord.Chord A2 E3> 155.5
# <music21.note.Note C> 156.0
# <music21.chord.Chord F2 C3> 156.0
# <music21.note.Note B-> 156.5
# <music21.note.Note C> 157.0
# <music21.note.Note G#> 157.5
# <music21.chord.Chord F2 C3> 157.5
# <music21.note.Note F> 158.0
# <music21.chord.Chord F2 C3> 158.0
# <music21.note.Note G> 159.0
# <music21.chord.Chord F2 C3> 159.0
# <music21.chord.Chord C4 E4 A4> 160.0
# <music21.chord.Chord A1 E2> 160.0
# <music21.chord.Chord C4 E4 A4> 161.0
# <music21.chord.Chord A1 E2> 161.0
# <music21.chord.Chord A1 E2> 161.5
# <music21.chord.Chord A1 E2> 162.0
# <music21.chord.Chord A1 E2> 163.0
# <music21.chord.Chord A1 E2> 163.5
# <music21.chord.Chord D4 F#4 B4> 164.0
# <music21.chord.Chord A1 F#2> 164.0
# <music21.chord.Chord D4 F#4 B4> 165.0
# <music21.chord.Chord A1 F#2> 165.0
# <music21.chord.Chord A1 F#2> 165.5
# <music21.chord.Chord A1 F#2> 166.0
# <music21.chord.Chord A1 F#2> 167.0
# <music21.chord.Chord A1 F#2> 167.5
# <music21.chord.Chord E4 G4 C5> 168.0
# <music21.chord.Chord A1 G2> 168.0
# <music21.chord.Chord E4 G4 C5> 169.0
# <music21.chord.Chord A1 G2> 169.0
# <music21.chord.Chord A1 G2> 169.5
# <music21.chord.Chord A1 G2> 170.0
# <music21.chord.Chord A1 G2> 171.0
# <music21.chord.Chord A1 G2> 171.5
# <music21.chord.Chord F#4 A4 D5> 172.0
# <music21.chord.Chord A1 A2> 172.0
# <music21.chord.Chord F#4 A4 D5> 172.5
# <music21.chord.Chord F#4 A4 D5> 173.0
# <music21.chord.Chord A1 A2> 173.0
# <music21.chord.Chord A1 A2> 173.5
# <music21.chord.Chord A1 A2> 174.0
# <music21.chord.Chord A1 A2> 175.0
# <music21.chord.Chord A1 A2> 175.5
# <music21.note.Note F> 176.0
# <music21.chord.Chord F4 G#4 C5> 177.0
# <music21.note.Note E-> 177.5
# <music21.note.Note C#> 178.0
# <music21.chord.Chord F4 G#4 C#5> 178.5
# <music21.chord.Chord F4 G#4 C#5> 179.0
# <music21.note.Note E-> 179.5
# <music21.note.Note F> 180.0
# <music21.chord.Chord F4 G#4 C5> 180.5
# <music21.chord.Chord F4 G#4 C5> 181.0
# <music21.note.Note G> 181.5
# <music21.note.Note G#> 182.0
# <music21.chord.Chord E4 G#4 B4> 182.5
# <music21.note.Note B-> 183.0
# <music21.chord.Chord E4 G#4 C#5> 183.5
# <music21.note.Note B> 184.0
# <music21.chord.Chord F#4 B4 D5> 185.0
# <music21.note.Note A> 185.5
# <music21.note.Note G> 186.0
# <music21.chord.Chord G4 B4 D5> 186.5
# <music21.chord.Chord G4 B4 D5> 187.0
# <music21.note.Note A> 187.5
# <music21.note.Note B> 188.0
# <music21.chord.Chord F#4 B4 D5> 188.5
# <music21.chord.Chord F#4 B4 D5> 189.0
# <music21.note.Note C#> 189.5
# <music21.chord.Chord F#4 B4 D5> 190.0
# <music21.note.Note D> 190.0
# <music21.chord.Chord F4 C5 D5> 191.0
# <music21.note.Note C#> 191.0
# <music21.chord.Chord C3 G3> 192.0
# <music21.note.Note G> 192.5
# <music21.note.Note G> 193.0
# <music21.note.Note G> 193.5
# <music21.note.Note G> 193.5
# <music21.note.Note B-> 194.0
# <music21.note.Note G#> 194.0
# <music21.chord.Chord C3 G3> 194.0
# <music21.note.Note G> 194.5
# <music21.note.Note G> 195.0
# <music21.note.Note G> 195.5
# <music21.note.Note G> 195.5
# <music21.note.Note B-> 196.0
# <music21.note.Note G#> 196.0
# <music21.chord.Chord C3 G3> 196.0
# <music21.note.Note G> 196.5
# <music21.note.Note B-> 197.0
# <music21.note.Note G#> 197.5
# <music21.note.Note G> 197.5
# <music21.note.Note G> 198.0
# <music21.chord.Chord C3 G3> 198.0
# <music21.note.Note G#> 198.5
# <music21.note.Note G> 199.0
# <music21.note.Note F> 199.5
# <music21.note.Note G> 199.5
# <music21.chord.Chord C3 G3> 200.0
# <music21.note.Note G> 200.5
# <music21.note.Note G> 201.0
# <music21.note.Note G> 201.5
# <music21.note.Note G> 201.5
# <music21.note.Note B-> 202.0
# <music21.note.Note G#> 202.0
# <music21.chord.Chord C3 G3> 202.0
# <music21.note.Note G> 202.5
# <music21.note.Note G> 203.0
# <music21.note.Note G> 203.5
# <music21.note.Note G> 203.5
# <music21.note.Note B-> 204.0
# <music21.note.Note G#> 204.0
# <music21.chord.Chord C3 G3> 204.0
# <music21.note.Note G> 204.5
# <music21.note.Note B-> 205.0
# <music21.note.Note G#> 205.5
# <music21.note.Note G> 205.5
# <music21.note.Note G> 206.0
# <music21.chord.Chord C3 G3> 206.0
# <music21.note.Note G#> 206.5
# <music21.note.Note G> 207.0
# <music21.note.Note E-> 207.5
# <music21.note.Note C#> 207.5
# <music21.chord.Chord D3 A3> 208.0
# <music21.note.Note A> 208.5
# <music21.note.Note A> 209.0
# <music21.note.Note A> 209.5
# <music21.note.Note A> 209.5
# <music21.note.Note C> 210.0
# <music21.note.Note B-> 210.0
# <music21.chord.Chord D3 A3> 210.0
# <music21.note.Note A> 210.5
# <music21.note.Note A> 211.0
# <music21.note.Note A> 211.5
# <music21.note.Note A> 211.5
# <music21.note.Note C> 212.0
# <music21.note.Note B-> 212.0
# <music21.chord.Chord D3 A3> 212.0
# <music21.note.Note A> 212.5
# <music21.note.Note C> 213.0
# <music21.note.Note B-> 213.5
# <music21.note.Note A> 213.5
# <music21.note.Note A> 214.0
# <music21.chord.Chord D3 A3> 214.0
# <music21.note.Note B-> 214.5
# <music21.note.Note A> 215.0
# <music21.note.Note G> 215.5
# <music21.note.Note A> 215.5
# <music21.chord.Chord D3 A3> 216.0
# <music21.note.Note A> 216.5
# <music21.note.Note A> 217.0
# <music21.note.Note A> 217.5
# <music21.note.Note A> 217.5
# <music21.note.Note C> 218.0
# <music21.note.Note B-> 218.0
# <music21.chord.Chord D3 A3> 218.0
# <music21.note.Note A> 218.5
# <music21.note.Note A> 219.0
# <music21.note.Note A> 219.5
# <music21.note.Note A> 219.5
# <music21.note.Note E-> 220.0
# <music21.note.Note F#> 220.5
# <music21.note.Note B-> 220.75
# <music21.note.Note F#> 221.0
# <music21.note.Note F> 221.5
# <music21.note.Note E> 222.0
# <music21.note.Note E> 222.0
# <music21.note.Note A> 222.5
# <music21.note.Note E> 223.0
# <music21.note.Note F> 223.0
# <music21.note.Note F> 223.5
# <music21.note.Note B-> 223.5
# <music21.note.Note E> 224.0
# <music21.note.Note E> 224.0
# <music21.note.Note A> 224.5
# <music21.note.Note E> 225.0
# <music21.note.Note F> 225.0
# <music21.note.Note F> 225.5
# <music21.note.Note B-> 225.5
# <music21.note.Note E> 226.0
# <music21.chord.Chord E3 A3> 226.0
# <music21.note.Note C> 226.5
# <music21.note.Note A> 227.0
# <music21.note.Note F> 227.0
# <music21.note.Note F> 227.5
# <music21.note.Note E> 228.0
# <music21.note.Note F#> 228.0
# <music21.note.Note C> 228.5
# <music21.note.Note A> 229.0
# <music21.note.Note G> 229.0
# <music21.note.Note F> 229.5
# <music21.note.Note E> 230.0
# <music21.note.Note G#> 230.0
# <music21.note.Note C> 230.5
# <music21.note.Note A> 231.0
# <music21.note.Note F> 231.5
# <music21.note.Note E> 232.0
# <music21.chord.Chord E2 B-2> 234.0
# <music21.chord.Chord E2 B-2> 235.0
# <music21.chord.Chord E2 B-2> 236.0
# <music21.chord.Chord E2 B-2> 236.5
# <music21.chord.Chord E2 B-2> 237.0
# <music21.chord.Chord E2 B-2> 237.5
# <music21.chord.Chord E3 A3> 238.0
# <music21.note.Note E> 238.0
# <music21.chord.Chord A1 E2> 238.0
# <music21.chord.Chord E3 A3> 239.0
# <music21.chord.Chord A1 E2> 239.0
# <music21.chord.Chord A1 E2> 239.5
# <music21.chord.Chord A1 E2> 240.0
# <music21.chord.Chord A1 E2> 241.0
# <music21.chord.Chord A1 E2> 241.5
# <music21.chord.Chord E3 B3> 242.0
# <music21.chord.Chord A1 E2> 242.0
# <music21.chord.Chord E3 B3> 243.0
# <music21.chord.Chord A1 E2> 243.0
# <music21.chord.Chord A1 E2> 243.5
# <music21.chord.Chord A1 E2> 244.0
# <music21.chord.Chord A1 E2> 245.0
# <music21.chord.Chord A1 E2> 245.5
# <music21.chord.Chord E3 C4> 246.0
# <music21.note.Note E> 246.0
# <music21.chord.Chord A1 E2> 246.0
# <music21.chord.Chord E3 C4> 247.0
# <music21.chord.Chord A1 E2> 247.0
# <music21.chord.Chord A1 E2> 247.5
# <music21.chord.Chord A1 E2> 248.0
# <music21.chord.Chord A1 E2> 249.0
# <music21.chord.Chord A1 E2> 249.5
# <music21.chord.Chord A3 D4> 250.0
# <music21.chord.Chord A1 E2> 250.0
# <music21.chord.Chord A3 D4> 250.5
# <music21.chord.Chord A3 D4> 251.0
# <music21.chord.Chord A1 E2> 251.0
# <music21.chord.Chord A1 E2> 251.5
# <music21.chord.Chord A1 E2> 252.0
# <music21.chord.Chord A1 E2> 253.0
# <music21.chord.Chord A1 E2> 253.5
# <music21.chord.Chord E4 A4> 254.0
# <music21.note.Note E> 254.0
# <music21.chord.Chord A1 E2> 254.0
# <music21.chord.Chord E4 A4> 255.0
# <music21.chord.Chord A1 E2> 255.0
# <music21.chord.Chord A1 E2> 255.5
# <music21.chord.Chord A1 E2> 256.0
# <music21.note.Note E> 256.5
# <music21.note.Note F> 256.75
# <music21.note.Note G#> 256.75
# <music21.note.Note A> 257.0
# <music21.chord.Chord A1 E2> 257.0
# <music21.chord.Chord A1 E2> 257.5
# <music21.chord.Chord F4 B4> 258.0
# <music21.chord.Chord A1 E2> 258.0
# <music21.chord.Chord F4 B4> 259.0
# <music21.chord.Chord A1 E2> 259.0
# <music21.chord.Chord A1 E2> 259.5
# <music21.chord.Chord A1 E2> 260.0
# <music21.note.Note E> 260.5
# <music21.note.Note F> 260.75
# <music21.note.Note G#> 260.75
# <music21.note.Note A> 261.0
# <music21.chord.Chord A1 E2> 261.0
# <music21.chord.Chord A1 E2> 261.5
# <music21.chord.Chord A4 C5> 262.0
# <music21.note.Note E> 262.0
# <music21.chord.Chord A1 E2> 262.0
# <music21.chord.Chord A4 C5> 263.0
# <music21.chord.Chord A1 E2> 263.0
# <music21.chord.Chord A1 E2> 263.5
# <music21.chord.Chord A1 E2> 264.0
# <music21.note.Note E> 264.5
# <music21.note.Note F> 264.75
# <music21.note.Note G#> 264.75
# <music21.note.Note A> 265.0
# <music21.chord.Chord A1 E2> 265.0
# <music21.chord.Chord A1 E2> 265.5
# <music21.chord.Chord B4 D5> 266.0
# <music21.chord.Chord A1 E2> 266.0
# <music21.chord.Chord B4 D5> 266.5
# <music21.chord.Chord B4 D5> 267.0
# <music21.chord.Chord A1 E2> 267.0
# <music21.chord.Chord A1 E2> 267.5
# <music21.chord.Chord A1 E2> 268.0
# <music21.note.Note E> 268.5
# <music21.note.Note F> 268.75
# <music21.note.Note G#> 268.75
# <music21.note.Note A> 269.0
# <music21.chord.Chord A1 E2> 269.0
# <music21.chord.Chord A1 E2> 269.5
# <music21.chord.Chord G4 B4 E-5> 270.0
# <music21.note.Note E-> 270.0
# <music21.chord.Chord G4 B4 E-5> 271.0
# <music21.note.Note B> 272.0
# <music21.note.Note G> 273.0
# <music21.chord.Chord A4 C#5 F5> 274.0
# <music21.note.Note F#> 274.0
# <music21.chord.Chord A4 C#5 F5> 275.0
# <music21.chord.Chord G4 B4 E-5> 278.0
# <music21.note.Note E-> 278.0
# <music21.chord.Chord G4 B4 E-5> 279.0
# <music21.note.Note G> 280.5
# <music21.note.Note B> 281.0
# <music21.note.Note E-> 281.5
# <music21.chord.Chord A4 C#5 F5> 282.0
# <music21.note.Note G#> 282.0
# <music21.chord.Chord A4 C#5 F5> 282.5
# <music21.chord.Chord A4 C#5 F5> 283.0
# <music21.note.Note F> 283.0
# <music21.note.Note F> 286.0
# <music21.note.Note F> 287.0
# <music21.note.Note F> 288.0
# <music21.note.Note F> 288.5
# <music21.note.Note F> 289.0
# <music21.chord.Chord E3 A3> 290.0
# <music21.note.Note E> 290.5
# <music21.chord.Chord E3 A3> 290.5
# <music21.note.Note C> 291.0
# <music21.chord.Chord E3 A3> 291.0
# <music21.note.Note A> 291.5
# <music21.chord.Chord E3 A3> 291.5
# <music21.chord.Chord F3 A3> 292.0
# <music21.note.Note F> 292.5
# <music21.chord.Chord F3 A3> 292.5
# <music21.note.Note C> 293.0
# <music21.chord.Chord F3 A3> 293.0
# <music21.note.Note A> 293.5
# <music21.chord.Chord F3 A3> 293.5
# <music21.chord.Chord E3 A3> 294.0
# <music21.note.Note E> 294.5
# <music21.chord.Chord E3 A3> 294.5
# <music21.note.Note C> 295.0
# <music21.chord.Chord E3 A3> 295.0
# <music21.note.Note A> 295.5
# <music21.chord.Chord E3 A3> 295.5
# <music21.note.Note F> 296.0
# <music21.chord.Chord F3 A3> 296.0
# <music21.note.Note C> 296.5
# <music21.chord.Chord F3 A3> 296.5
# <music21.note.Note E> 297.0
# <music21.chord.Chord F3 A3> 297.0
# <music21.note.Note D> 297.5
# <music21.chord.Chord F3 A3> 297.5
# <music21.note.Note E> 298.0
# <music21.chord.Chord E3 A3> 298.0
# <music21.note.Note E-> 298.5
# <music21.chord.Chord E3 A3> 298.5
# <music21.note.Note B> 299.0
# <music21.chord.Chord E3 A3> 299.0
# <music21.chord.Chord E3 A3> 299.5
# <music21.note.Note A> 300.0
# <music21.chord.Chord F3 A3> 300.0
# <music21.chord.Chord F3 A3> 300.5
# <music21.chord.Chord F3 A3> 301.0
# <music21.chord.Chord F3 A3> 301.5
# <music21.chord.Chord E3 A3> 302.0
# <music21.chord.Chord E3 A3> 302.5
# <music21.chord.Chord E3 A3> 303.0
# <music21.chord.Chord E3 A3> 303.5
# <music21.chord.Chord F3 A3> 304.0
# <music21.chord.Chord F3 A3> 304.5
# <music21.chord.Chord F3 A3> 305.0
# <music21.chord.Chord F3 A3> 305.5
# <music21.note.Note B> 306.0
# <music21.chord.Chord E3 A3> 306.0
# <music21.note.Note A> 306.5
# <music21.chord.Chord E3 A3> 306.5
# <music21.note.Note E> 307.0
# <music21.chord.Chord E3 A3> 307.0
# <music21.chord.Chord E3 A3> 307.5
# <music21.note.Note E-> 308.0
# <music21.chord.Chord F3 A3> 308.0
# <music21.chord.Chord F3 A3> 308.5
# <music21.chord.Chord F3 A3> 309.0
# <music21.chord.Chord F3 A3> 309.5
# <music21.chord.Chord E3 A3> 310.0
# <music21.chord.Chord E3 A3> 310.5
# <music21.chord.Chord E3 A3> 311.0
# <music21.chord.Chord E3 A3> 311.5
# <music21.chord.Chord F3 A3> 312.0
# <music21.chord.Chord F3 A3> 312.5
# <music21.chord.Chord F3 A3> 313.0
# <music21.chord.Chord F3 A3> 313.5
# <music21.note.Note E> 314.0
# <music21.chord.Chord E2 E3> 314.0
# <music21.note.Note E-> 314.5
# <music21.note.Note C> 315.0
# <music21.note.Note E> 316.0
# <music21.chord.Chord F2 F3> 316.0
# <music21.note.Note E-> 316.5
# <music21.note.Note B> 317.0
# <music21.note.Note E> 318.0
# <music21.chord.Chord F#2 F#3> 318.0
# <music21.note.Note E-> 318.5
# <music21.note.Note C> 319.0
# <music21.note.Note A> 320.0
# <music21.chord.Chord F2 F3> 320.0
# <music21.note.Note A> 322.0
# <music21.chord.Chord E2 E3> 322.0
# <music21.note.Note C> 322.5
# <music21.note.Note E> 323.0
# <music21.note.Note F> 323.5
# <music21.note.Note E> 324.0
# <music21.chord.Chord F2 F3> 324.0
# <music21.note.Note C> 324.5
# <music21.note.Note A> 325.0
# <music21.note.Note C> 325.5
# <music21.note.Note A> 326.0
# <music21.chord.Chord F#2 F#3> 326.0
# <music21.note.Note C> 326.5
# <music21.note.Note E> 327.0
# <music21.note.Note F#> 327.5
# <music21.note.Note E> 328.0
# <music21.chord.Chord F2 F3> 328.0
# <music21.note.Note C> 328.5
# <music21.note.Note A> 329.0
# <music21.note.Note C> 329.5
# <music21.note.Note A> 330.0
# <music21.chord.Chord E2 E3> 330.0
# <music21.note.Note C> 330.5
# <music21.note.Note E> 331.0
# <music21.note.Note F> 331.5
# <music21.note.Note E> 332.0
# <music21.chord.Chord F2 F3> 332.0
# <music21.note.Note C> 332.5
# <music21.note.Note A> 333.0
# <music21.note.Note C> 333.5
# <music21.note.Note A> 334.0
# <music21.chord.Chord F#2 F#3> 334.0
# <music21.note.Note C> 334.5
# <music21.note.Note E> 335.0
# <music21.note.Note F#> 335.5
# <music21.note.Note E> 336.0
# <music21.chord.Chord F2 F3> 336.0
# <music21.note.Note C> 336.5
# <music21.note.Note A> 337.0
# <music21.note.Note C> 337.5
# <music21.note.Note A> 338.0
# <music21.note.Note A> 338.0
# <music21.note.Note C> 338.5
# <music21.note.Note E> 339.0
# <music21.note.Note F> 339.5
# <music21.note.Note A> 339.5
# <music21.note.Note E> 340.0
# <music21.note.Note A> 340.0
# <music21.note.Note C> 340.5
# <music21.note.Note B> 341.0
# <music21.note.Note C> 341.5
# <music21.note.Note A> 342.0
# <music21.note.Note A> 342.0
# <music21.note.Note F> 342.5
# <music21.note.Note E> 343.0
# <music21.note.Note F> 343.5
# <music21.note.Note A> 343.5
# <music21.note.Note E> 344.0
# <music21.note.Note A> 344.0
# <music21.note.Note C> 344.5
# <music21.note.Note B> 345.0
# <music21.note.Note C> 345.5
# <music21.note.Note E> 346.0
# <music21.chord.Chord A2 E3> 346.0
# <music21.note.Note B> 347.0
# <music21.chord.Chord A2 E3> 347.5
# <music21.note.Note A> 348.0
# <music21.chord.Chord A2 E3> 348.0
# <music21.note.Note G> 348.5
# <music21.note.Note F> 349.0
# <music21.chord.Chord A2 E3> 349.0
# <music21.chord.Chord A2 E3> 349.5
# <music21.note.Note E> 350.0
# <music21.chord.Chord B-2 F3> 350.0
# <music21.note.Note F> 350.5
# <music21.note.Note G> 351.0
# <music21.note.Note D> 351.5
# <music21.chord.Chord B-2 F3> 351.5
# <music21.note.Note F> 352.0
# <music21.chord.Chord B-2 F3> 352.0
# <music21.note.Note E> 353.0
# <music21.chord.Chord B-2 F3> 353.0
# <music21.note.Note D> 353.5
# <music21.chord.Chord B-2 F3> 353.5
# <music21.note.Note E> 354.0
# <music21.chord.Chord A2 E3> 354.0
# <music21.note.Note B> 355.0
# <music21.note.Note C> 355.5
# <music21.chord.Chord A2 E3> 355.5
# <music21.note.Note D> 356.0
# <music21.chord.Chord A2 E3> 356.0
# <music21.note.Note C> 357.0
# <music21.chord.Chord A2 E3> 357.0
# <music21.note.Note B> 357.5
# <music21.chord.Chord A2 E3> 357.5
# <music21.note.Note C> 358.0
# <music21.chord.Chord F2 C3> 358.0
# <music21.note.Note B> 358.5
# <music21.note.Note C> 359.0
# <music21.note.Note A> 359.5
# <music21.chord.Chord F2 C3> 359.5
# <music21.note.Note F> 360.0
# <music21.chord.Chord F2 C3> 360.0
# <music21.note.Note G> 361.0
# <music21.chord.Chord F2 C3> 361.0
# <music21.chord.Chord E4 A4> 362.0
# <music21.chord.Chord A1 E2> 362.0
# <music21.chord.Chord E4 A4> 363.0
# <music21.chord.Chord A1 E2> 363.0
# <music21.chord.Chord A1 E2> 363.5
# <music21.note.Note G> 364.0
# <music21.chord.Chord A1 E2> 364.0
# <music21.note.Note F#> 364.5
# <music21.note.Note E> 365.0
# <music21.chord.Chord A1 E2> 365.0
# <music21.chord.Chord A1 E2> 365.5
# <music21.chord.Chord A4 B4> 366.0
# <music21.chord.Chord A1 E2> 366.0
# <music21.chord.Chord A4 B4> 367.0
# <music21.chord.Chord A1 E2> 367.0
# <music21.chord.Chord A1 E2> 367.5
# <music21.note.Note E-> 368.0
# <music21.note.Note D> 368.0
# <music21.chord.Chord A1 E2> 368.0
# <music21.note.Note C> 368.5
# <music21.note.Note D> 369.0
# <music21.chord.Chord A1 E2> 369.0
# <music21.note.Note E> 369.5
# <music21.chord.Chord A1 E2> 369.5
# <music21.chord.Chord A4 C5> 370.0
# <music21.chord.Chord A1 E2> 370.0
# <music21.chord.Chord A4 C5> 371.0
# <music21.chord.Chord A1 E2> 371.0
# <music21.chord.Chord A1 E2> 371.5
# <music21.note.Note C> 372.0
# <music21.chord.Chord A1 E2> 372.0
# <music21.note.Note G#> 372.5
# <music21.note.Note A> 373.0
# <music21.chord.Chord A1 E2> 373.0
# <music21.note.Note C> 373.5
# <music21.chord.Chord A1 E2> 373.5
# <music21.chord.Chord B4 D5> 374.0
# <music21.chord.Chord A1 E2> 374.0
# <music21.chord.Chord B4 D5> 374.5
# <music21.chord.Chord B4 D5> 375.0
# <music21.chord.Chord A1 E2> 375.0
# <music21.chord.Chord A1 E2> 375.5
# <music21.note.Note C> 376.0
# <music21.chord.Chord A1 E2> 376.0
# <music21.note.Note G> 376.25
# <music21.note.Note G#> 376.5
# <music21.note.Note B> 376.75
# <music21.note.Note A> 377.0
# <music21.chord.Chord A1 E2> 377.0
# <music21.note.Note E> 378.0
# <music21.chord.Chord A2 E3> 378.0
# <music21.note.Note B> 379.0
# <music21.chord.Chord A2 E3> 379.5
# <music21.note.Note A> 380.0
# <music21.chord.Chord A2 E3> 380.0
# <music21.note.Note G> 380.5
# <music21.note.Note F> 381.0
# <music21.chord.Chord A2 E3> 381.0
# <music21.chord.Chord A2 E3> 381.5
# <music21.note.Note E> 382.0
# <music21.chord.Chord B-2 F3> 382.0
# <music21.note.Note F> 382.5
# <music21.note.Note G> 383.0
# <music21.note.Note D> 383.5
# <music21.chord.Chord B-2 F3> 383.5
# <music21.note.Note F> 384.0
# <music21.chord.Chord B-2 F3> 384.0
# <music21.note.Note E> 385.0
# <music21.chord.Chord B-2 F3> 385.0
# <music21.note.Note D> 385.5
# <music21.chord.Chord B-2 F3> 385.5
# <music21.note.Note E> 386.0
# <music21.chord.Chord A2 E3> 386.0
# <music21.note.Note B> 387.0
# <music21.note.Note C> 387.5
# <music21.chord.Chord A2 E3> 387.5
# <music21.note.Note D> 388.0
# <music21.chord.Chord A2 E3> 388.0
# <music21.note.Note C> 389.0
# <music21.chord.Chord A2 E3> 389.0
# <music21.note.Note B> 389.5
# <music21.chord.Chord A2 E3> 389.5
# <music21.note.Note C> 390.0
# <music21.chord.Chord F2 C3> 390.0
# <music21.note.Note B-> 390.5
# <music21.note.Note C> 391.0
# <music21.note.Note G#> 391.5
# <music21.chord.Chord F2 C3> 391.5
# <music21.note.Note F> 392.0
# <music21.chord.Chord F2 C3> 392.0
# <music21.note.Note G> 393.0
# <music21.chord.Chord F2 C3> 393.0
# <music21.chord.Chord C4 E4 A4> 394.0
# <music21.chord.Chord A1 E2> 394.0
# <music21.chord.Chord C4 E4 A4> 395.0
# <music21.chord.Chord A1 E2> 395.0
# <music21.chord.Chord A1 E2> 395.5
# <music21.chord.Chord A1 E2> 396.0
# <music21.chord.Chord A1 E2> 397.0
# <music21.chord.Chord A1 E2> 397.5
# <music21.chord.Chord D4 F#4 B4> 398.0
# <music21.chord.Chord A1 F#2> 398.0
# <music21.chord.Chord D4 F#4 B4> 399.0
# <music21.chord.Chord A1 F#2> 399.0
# <music21.chord.Chord A1 F#2> 399.5
# <music21.chord.Chord A1 F#2> 400.0
# <music21.chord.Chord A1 F#2> 401.0
# <music21.chord.Chord A1 F#2> 401.5
# <music21.chord.Chord E4 G4 C5> 402.0
# <music21.chord.Chord A1 G2> 402.0
# <music21.chord.Chord E4 G4 C5> 403.0
# <music21.chord.Chord A1 G2> 403.0
# <music21.chord.Chord A1 G2> 403.5
# <music21.chord.Chord A1 G2> 404.0
# <music21.chord.Chord A1 G2> 405.0
# <music21.chord.Chord A1 G2> 405.5
# <music21.chord.Chord F#4 A4 D5> 406.0
# <music21.chord.Chord A1 A2> 406.0
# <music21.chord.Chord F#4 A4 D5> 406.5
# <music21.chord.Chord F#4 A4 D5> 407.0
# <music21.chord.Chord A1 A2> 407.0
# <music21.chord.Chord A1 A2> 407.5
# <music21.chord.Chord A1 A2> 408.0
# <music21.chord.Chord A1 A2> 409.0
# <music21.chord.Chord A1 A2> 409.5
# <music21.note.Note F> 410.0
# <music21.chord.Chord F4 G#4 C5> 411.0
# <music21.note.Note E-> 411.5
# <music21.note.Note C#> 412.0
# <music21.chord.Chord F4 G#4 C#5> 412.5
# <music21.chord.Chord F4 G#4 C#5> 413.0
# <music21.note.Note E-> 413.5
# <music21.note.Note F> 414.0
# <music21.chord.Chord F4 G#4 C5> 414.5
# <music21.chord.Chord F4 G#4 C5> 415.0
# <music21.note.Note G> 415.5
# <music21.note.Note G#> 416.0
# <music21.chord.Chord E4 G#4 B4> 416.5
# <music21.note.Note B-> 417.0
# <music21.chord.Chord E4 G#4 C#5> 417.5
# <music21.note.Note B> 418.0
# <music21.chord.Chord F#4 B4 D5> 419.0
# <music21.note.Note A> 419.5
# <music21.note.Note G> 420.0
# <music21.chord.Chord G4 B4 D5> 420.5
# <music21.chord.Chord G4 B4 D5> 421.0
# <music21.note.Note A> 421.5
# <music21.note.Note B> 422.0
# <music21.chord.Chord F#4 B4 D5> 422.5
# <music21.chord.Chord F#4 B4 D5> 423.0
# <music21.note.Note C#> 423.5
# <music21.chord.Chord F#4 B4 D5> 424.0
# <music21.note.Note D> 424.0
# <music21.chord.Chord F4 C5 D5> 425.0
# <music21.note.Note C#> 425.0
# <music21.chord.Chord C3 G3> 426.0
# <music21.note.Note G> 426.5
# <music21.note.Note G> 427.0
# <music21.note.Note G> 427.5
# <music21.note.Note G> 427.5
# <music21.note.Note B-> 428.0
# <music21.note.Note G#> 428.0
# <music21.chord.Chord C3 G3> 428.0
# <music21.note.Note G> 428.5
# <music21.note.Note G> 429.0
# <music21.note.Note G> 429.5
# <music21.note.Note G> 429.5
# <music21.note.Note B-> 430.0
# <music21.note.Note G#> 430.0
# <music21.chord.Chord C3 G3> 430.0
# <music21.note.Note G> 430.5
# <music21.note.Note B-> 431.0
# <music21.note.Note G#> 431.5
# <music21.note.Note G> 431.5
# <music21.note.Note G> 432.0
# <music21.chord.Chord C3 G3> 432.0
# <music21.note.Note G#> 432.5
# <music21.note.Note G> 433.0
# <music21.note.Note F> 433.5
# <music21.note.Note G> 433.5
# <music21.chord.Chord C3 G3> 434.0
# <music21.note.Note G> 434.5
# <music21.note.Note G> 435.0
# <music21.note.Note G> 435.5
# <music21.note.Note G> 435.5
# <music21.note.Note B-> 436.0
# <music21.note.Note G#> 436.0
# <music21.chord.Chord C3 G3> 436.0
# <music21.note.Note G> 436.5
# <music21.note.Note G> 437.0
# <music21.note.Note G> 437.5
# <music21.note.Note G> 437.5
# <music21.note.Note B-> 438.0
# <music21.note.Note G#> 438.0
# <music21.chord.Chord C3 G3> 438.0
# <music21.note.Note G> 438.5
# <music21.note.Note B-> 439.0
# <music21.note.Note G#> 439.5
# <music21.note.Note G> 439.5
# <music21.note.Note G> 440.0
# <music21.chord.Chord C3 G3> 440.0
# <music21.note.Note G#> 440.5
# <music21.note.Note G> 441.0
# <music21.note.Note E-> 441.5
# <music21.note.Note C#> 441.5
# <music21.chord.Chord D3 A3> 442.0
# <music21.note.Note A> 442.5
# <music21.note.Note A> 443.0
# <music21.note.Note A> 443.5
# <music21.note.Note A> 443.5
# <music21.note.Note C> 444.0
# <music21.note.Note B-> 444.0
# <music21.chord.Chord D3 A3> 444.0
# <music21.note.Note A> 444.5
# <music21.note.Note A> 445.0
# <music21.note.Note A> 445.5
# <music21.note.Note A> 445.5
# <music21.note.Note C> 446.0
# <music21.note.Note B-> 446.0
# <music21.chord.Chord D3 A3> 446.0
# <music21.note.Note A> 446.5
# <music21.note.Note C> 447.0
# <music21.note.Note B-> 447.5
# <music21.note.Note A> 447.5
# <music21.note.Note A> 448.0
# <music21.chord.Chord D3 A3> 448.0
# <music21.note.Note B-> 448.5
# <music21.note.Note A> 449.0
# <music21.note.Note G> 449.5
# <music21.note.Note A> 449.5
# <music21.chord.Chord D3 A3> 450.0
# <music21.note.Note A> 450.5
# <music21.note.Note A> 451.0
# <music21.note.Note A> 451.5
# <music21.note.Note A> 451.5
# <music21.note.Note C> 452.0
# <music21.note.Note B-> 452.0
# <music21.chord.Chord D3 A3> 452.0
# <music21.note.Note A> 452.5
# <music21.note.Note A> 453.0
# <music21.note.Note A> 453.5
# <music21.note.Note A> 453.5
# <music21.note.Note E-> 454.0
# <music21.note.Note F#> 454.5
# <music21.note.Note B-> 454.75
# <music21.note.Note F#> 455.0
# <music21.note.Note F> 455.5
# <music21.note.Note E> 456.0
# <music21.note.Note E> 456.0
# <music21.note.Note A> 456.5
# <music21.note.Note E> 457.0
# <music21.note.Note F> 457.0
# <music21.note.Note F> 457.5
# <music21.note.Note B-> 457.5
# <music21.note.Note E> 458.0
# <music21.note.Note E> 458.0
# <music21.note.Note A> 458.5
# <music21.note.Note E> 459.0
# <music21.note.Note F> 459.0
# <music21.note.Note F> 459.5
# <music21.note.Note B-> 459.5
# <music21.note.Note E> 460.0
# <music21.chord.Chord E3 A3> 460.0
# <music21.note.Note C> 460.5
# <music21.note.Note A> 461.0
# <music21.note.Note F> 461.0
# <music21.note.Note F> 461.5
# <music21.note.Note E> 462.0
# <music21.note.Note F#> 462.0
# <music21.note.Note C> 462.5
# <music21.note.Note A> 463.0
# <music21.note.Note G> 463.0
# <music21.note.Note F> 463.5
# <music21.note.Note E> 464.0
# <music21.note.Note G#> 464.0
# <music21.note.Note C> 464.5
# <music21.note.Note A> 465.0
# <music21.note.Note F> 465.5
# <music21.note.Note E> 466.0
# <music21.chord.Chord E2 B-2> 468.0
# <music21.chord.Chord E2 B-2> 469.0
# <music21.chord.Chord E2 B-2> 470.0
# <music21.chord.Chord E2 B-2> 470.5
# <music21.chord.Chord E2 B-2> 471.0
# <music21.chord.Chord E2 B-2> 471.5
# <music21.chord.Chord E4 A4> 472.0
# <music21.note.Note E> 472.0
# <music21.note.Note A> 472.0
# <music21.chord.Chord E4 A4> 473.0
# <music21.chord.Chord A1 E2> 473.0

# %%
notes_demo = []

for ele in elements_to_parse:
    # If the element is a Note,  then store it's pitch
    if isinstance(ele, note.Note):
        notes_demo.append(str(ele.pitch))
    
    # If the element is a Chord, split each note of chord and join them with +
    elif isinstance(ele, chord.Chord):
        notes_demo.append("+".join(str(n) for n in ele.normalOrder))

# %%
len(notes_demo)
# Out:
# 1171

# %%
isinstance(elements_to_parse[68], chord.Chord)
# Out:
# False

# %%
notes = []

for file in glob.glob("/content/drive/MyDrive/Music datasets/midi_songs/*.mid"):
    midi = converter.parse(file) # Convert file into stream.Score Object
    
    print("parsing %s"%file)
    
    elements_to_parse = midi.flat.notes
    
    
    for ele in elements_to_parse:
        # If the element is a Note,  then store it's pitch
        if isinstance(ele, note.Note):
            notes.append(str(ele.pitch))

        # If the element is a Chord, split each note of chord and join them with +
        elif isinstance(ele, chord.Chord):
            notes.append("+".join(str(n) for n in ele.normalOrder))
# Out:
# parsing /content/drive/MyDrive/Music datasets/midi_songs/FF4.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Eternal_Harvest.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/FFIX_Piano.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Cids.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/BlueStone_LastDungeon.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/FF8_Shuffle_or_boogie_pc.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/FFIXQuMarshP.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/FF3_Third_Phase_Final_(Piano).mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/0fithos.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/FF3_Battle_(Piano).mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/DOS.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/FF6epitaph_piano.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/8.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/EyesOnMePiano.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/AT.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/FFIII_Edgar_And_Sabin_Piano.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Rachel_Piano_tempofix.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ahead_on_our_way_piano.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Kingdom_Hearts_Dearly_Beloved.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Fyw_piano.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Rydia_pc.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Ff4-BattleLust.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Fiend_Battle_(Piano).mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Still_Alive-1.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/FFVII_BATTLE.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Ff7-One_Winged.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Gold_Silver_Rival_Battle.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Ff7-Cinco.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/OTD5YA.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/JENOVA.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Kingdom_Hearts_Traverse_Town.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Finalfantasy6fanfarecomplete.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Finalfantasy5gilgameshp.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Final_Fantasy_Matouyas_Cave_Piano.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/FFX_-_Ending_Theme_(Piano_Version)_-_by_Angel_FF.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Zelda_Overworld.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Final_Fantasy_7_-_Judgement_Day_Piano.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Oppressed.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Suteki_Da_Ne_(Piano_Version).mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/VincentPiano.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Life_Stream.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Fierce_Battle_(Piano).mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/In_Zanarkand.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/HighwindTakestotheSkies.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/Ff7-Jenova_Absolute.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ViviinAlexandria.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/costadsol.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/caitsith.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/dayafter.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/decisive.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/gerudo.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/lurk_in_dark.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/braska.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ff4-airship.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/dontbeafraid.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/cosmo.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ff8-lfp.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/fortresscondor.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/mining.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ff6shap.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ff4_piano_collections-main_theme.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/goldsaucer.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/figaro.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ff1battp.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ff11_awakening_piano.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ff7themep.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/bcm.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ff4-town.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ff7-mainmidi.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ff4-fight1.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/great_war.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ff4pclov.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/balamb.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/electric_de_chocobo.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/sera_.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/relmstheme-piano.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/sobf.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/waltz_de_choco.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/redwings.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/tpirtsd-piano.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ultimafro.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/ultros.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/path_of_repentance.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/pkelite4.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/tifap.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/z_aeristhemepiano.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/thoughts.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/thenightmarebegins.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/rufus.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/roseofmay-piano.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/traitor.mid
# parsing /content/drive/MyDrive/Music datasets/midi_songs/sandy.mid

# %%
len(notes)
# Out:
# 60498

# %%
with open("notes", 'wb') as filepath:
    pickle.dump(notes, filepath)

# %%
with open("notes", 'rb') as f:
    notes= pickle.load(f)

# %%
n_vocab = len(set(notes))

# %%
print("Total notes- ", len(notes))
print("Unique notes- ",  n_vocab)
# Out:
# Total notes-  60498
# Unique notes-  359

# %%
print(notes[100:200])
# Out:
# ['A5', 'E5', 'C5', 'A4', 'A5', 'E5', 'C5', 'A4', 'A5', 'E5', 'C5', 'A4', 'G5', 'D5', 'B4', 'G4', 'G5', 'D5', 'B4', 'G4', 'G5', 'D5', 'B4', 'G4', 'G5', 'D5', 'B4', 'G4', 'A5', 'E5', 'C5', 'A4', 'A5', 'E5', 'C5', 'A4', 'C6', 'A5', 'E5', 'C5', 'C6', 'A5', 'E5', 'C5', 'E6', 'C6', 'A5', 'E5', 'E6', 'C6', 'A5', 'E5', 'G6', 'E6', 'C6', 'G5', 'G6', 'E6', 'C6', 'G5', 'F#6', 'C6', 'A5', 'F#5', 'F#6', 'C6', 'A5', 'F#5', 'F#6', 'C6', 'A5', 'F#5', 'F#6', 'C6', 'A5', 'F#5', 'D6', 'A5', 'F#5', 'D5', 'D6', 'A5', 'F#5', 'D5', 'D6', 'A5', 'F#5', 'D5', 'D6', 'A5', 'F#5', 'D5', 'F6', 'C6', 'A5', 'F5', 'F6', 'C6', 'A5', 'F5']

# %%
# How many elements LSTM input should consider
sequence_length = 100

# %%
# All unique classes
pitchnames = sorted(set(notes))

# %%
# Mapping between ele to int value
ele_to_int = dict( (ele, num) for num, ele in enumerate(pitchnames) )

# %%
network_input = []
network_output = []

# %%
for i in range(len(notes) - sequence_length):
    seq_in = notes[i : i+sequence_length] # contains 100 values
    seq_out = notes[i + sequence_length]
    
    network_input.append([ele_to_int[ch] for ch in seq_in])
    network_output.append(ele_to_int[seq_out])

# %%
# No. of examples
n_patterns = len(network_input)
print(n_patterns)
# Out:
# 60398

# %%
# Desired shape for LSTM
network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))
print(network_input.shape)
# Out:
# (60398, 100, 1)

# %%
normalised_network_input = network_input/float(n_vocab)

# %%
# Network output are the classes, encode into one hot vector
network_output = np_utils.to_categorical(network_output)

# %%
network_output.shape
# Out:
# (60398, 359)

# %%
print(normalised_network_input.shape)
print(network_output.shape)
# Out:
# (60398, 100, 1)
# (60398, 359)

# %%
from keras.models import Sequential, load_model
from keras.layers import *
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential()
model.add( LSTM(units=512,
               input_shape = (normalised_network_input.shape[1], normalised_network_input.shape[2]),
               return_sequences = True) )
model.add( Dropout(0.3) )
model.add( LSTM(512, return_sequences=True) )
model.add( Dropout(0.3) )
model.add( LSTM(512) )
model.add( Dense(256) )
model.add( Dropout(0.3) )
model.add( Dense(n_vocab, activation="softmax") )

# %%
model.compile(loss="categorical_crossentropy", optimizer="adam")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 512)          1052672
# _________________________________________________________________
# dropout (Dropout)            (None, 100, 512)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 512)          2099200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 512)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 512)               2099200
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 359)               92263
# =================================================================
# Total params: 5,474,663
# Trainable params: 5,474,663
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint("model.hdf5", monitor='loss', verbose=0, save_best_only=True, mode='min')


model_his = model.fit(normalised_network_input, network_output, epochs=30, batch_size=64, callbacks=[checkpoint])
# Out:
# Epoch 1/30
# 944/944 [==============================] - 180s 185ms/step - loss: 4.7888
# Epoch 2/30
# 944/944 [==============================] - 175s 185ms/step - loss: 4.5267
# Epoch 3/30
# 944/944 [==============================] - 175s 185ms/step - loss: 4.3891
# Epoch 4/30
# 944/944 [==============================] - 175s 185ms/step - loss: 4.2053
# Epoch 5/30
# 944/944 [==============================] - 175s 185ms/step - loss: 3.9574
# Epoch 6/30
# 944/944 [==============================] - 175s 185ms/step - loss: 3.6645
# Epoch 7/30
# 944/944 [==============================] - 175s 185ms/step - loss: 3.3324
# Epoch 8/30
# 944/944 [==============================] - 174s 185ms/step - loss: 3.0138
# Epoch 9/30
# 944/944 [==============================] - 174s 185ms/step - loss: 2.6981
# Epoch 10/30
# 944/944 [==============================] - 175s 185ms/step - loss: 2.4293
# Epoch 11/30
# 944/944 [==============================] - 176s 186ms/step - loss: 2.1708
# Epoch 12/30
# 944/944 [==============================] - 175s 186ms/step - loss: 1.9757
# Epoch 13/30
# 944/944 [==============================] - 175s 185ms/step - loss: 1.7596
# Epoch 14/30
# 944/944 [==============================] - 175s 186ms/step - loss: 1.5875
# Epoch 15/30
# 944/944 [==============================] - 176s 186ms/step - loss: 1.4515
# Epoch 16/30
# 944/944 [==============================] - 175s 186ms/step - loss: 1.3119
# Epoch 17/30
# 944/944 [==============================] - 175s 185ms/step - loss: 1.1812
# Epoch 18/30
# 944/944 [==============================] - 175s 185ms/step - loss: 1.0825
# Epoch 19/30
# 944/944 [==============================] - 175s 185ms/step - loss: 0.9730
# Epoch 20/30
# 944/944 [==============================] - 175s 185ms/step - loss: 0.8945
# Epoch 21/30
# 944/944 [==============================] - 175s 185ms/step - loss: 0.8285
# Epoch 22/30
# 944/944 [==============================] - 175s 185ms/step - loss: 0.7624
# Epoch 23/30
# 944/944 [==============================] - 175s 185ms/step - loss: 0.6921
# Epoch 24/30
# 944/944 [==============================] - 175s 186ms/step - loss: 0.6344
# Epoch 25/30
# 944/944 [==============================] - 175s 185ms/step - loss: 0.5993
# Epoch 26/30
# 944/944 [==============================] - 175s 186ms/step - loss: 0.5615
# Epoch 27/30
# 944/944 [==============================] - 176s 186ms/step - loss: 0.5178
# Epoch 28/30
# 944/944 [==============================] - 176s 186ms/step - loss: 0.4860
# Epoch 29/30
# 944/944 [==============================] - 175s 186ms/step - loss: 0.4498
# Epoch 30/30
# 944/944 [==============================] - 175s 185ms/step - loss: 0.4229

# %%
model = load_model("/content/model.hdf5")

# %%
sequence_length = 100
network_input = []

for i in range(len(notes) - sequence_length):
    seq_in = notes[i : i+sequence_length] # contains 100 values
    network_input.append([ele_to_int[ch] for ch in seq_in])

# %%
# Any random start index
start = np.random.randint(len(network_input) - 1)

# Mapping int_to_ele
int_to_ele = dict((num, ele) for num, ele in enumerate(pitchnames))

# Initial pattern 
pattern = network_input[start]
prediction_output = []

# generate 200 elements
for note_index in range(200):
    prediction_input = np.reshape(pattern, (1, len(pattern), 1)) # convert into numpy desired shape 
    prediction_input = prediction_input/float(n_vocab) # normalise
    
    prediction =  model.predict(prediction_input, verbose=0)
    
    idx = np.argmax(prediction)
    result = int_to_ele[idx]
    prediction_output.append(result) 
    
    # Remove the first value, and append the recent value.. 
    # This way input is moving forward step-by-step with time..
    pattern.append(idx)
    pattern = pattern[1:]

# %%
print(prediction_output)
# Out:
# ['2', 'A2', '2+4+7', '2', 'A2', '2+5+9', '2', 'A2', '7+10+2', '2', 'A2', '2+5+9', '2', 'A2', '9+0+2', '2', 'A2', '7+10+2', '2', 'A2', '2+5+9', '2', 'A2', '7+10+2', '2', 'A2', '2+4+7', '2', 'A2', '2+5+9', '2', 'A2', 'D5', '2', 'F4', 'E4', 'D4', '2', 'D4', 'E4', 'F4', 'B-4', 'A4', '2', '8+9', '8+9', '8+9', '8+9+2', 'F3', 'C3', 'E3', 'B-2', 'D3', 'F2', '2', 'D2', 'D3', 'D4', 'A2', 'B4', 'F2', 'D3', 'A4', 'F2', 'D3', 'A2', 'A2', '2', '2', 'F2', '2+4+7', 'D2', '0+2+6', '9+0+2+5', '2', 'F2', '5', 'F2', 'F2', 'F2', 'F2', 'F2', '2+5', 'D4', 'D4', 'B4', 'B4', 'B4', '5+9', 'C#5', 'A4', 'B4', 'B4', 'C#5', 'C#5', 'C5', 'D5', 'E-5', 'G#4', 'B-2', 'B-4', '9+0', 'A2', 'C5', 'F#4', 'E-3', 'C#5', 'F#2', '5+8+0', 'A4', 'F#2', 'B4', 'B-4', '6+10', 'C5', 'F#2', 'A2', 'B4', '5', 'C#5', 'D3', 'C#5', 'B4', 'E4', '3+8', 'E-4', 'C5', 'D5', 'B4', 'B4', 'C5', 'C#5', 'D5', '9+2', 'C5', '9+0', 'B4', 'F3', 'A4', 'A4', '4', 'D3', 'D3', 'B4', 'D3', 'D4', '11+2', 'D3', 'D3', 'D4', 'D3', 'A4', 'C5', 'D3', 'D4', 'D3', 'D3', 'A3', 'D3', 'D3', 'B4', '1+4', '9+2', 'C6', 'A3', 'C6', 'A3', 'A2', 'C#4', 'C#4', 'G3', 'D5', 'A3', 'C4', 'C4', 'D4', 'A3', 'C5', 'F3', 'C4', 'B3', 'C4', 'A5', 'C6', 'A3', 'E5', 'B3', 'G#3', 'D4', 'B3', 'C6', 'G3', 'C6', 'C4', 'B5', '3+7', '9', 'E4', '2+7', 'A1']

# %%
offset = 0 # Time
output_notes = []

for pattern in prediction_output:
    
    # if the pattern is a chord
    if ('+' in pattern) or pattern.isdigit():
        notes_in_chord = pattern.split('+')
        temp_notes = []
        for current_note in notes_in_chord:
            new_note = note.Note(int(current_note))  # create Note object for each note in the chord
            new_note.storedInstrument = instrument.Piano()
            temp_notes.append(new_note)
            
        
        new_chord = chord.Chord(temp_notes) # creates the chord() from the list of notes
        new_chord.offset = offset
        output_notes.append(new_chord)
    
    else:
            # if the pattern is a note
        new_note = note.Note(pattern)
        new_note.offset = offset
        new_note.storedInstrument = instrument.Piano()
        output_notes.append(new_note)
        
    offset += 0.5

# %%
# create a stream object from the generated notes
midi_stream = stream.Stream(output_notes)
midi_stream.write('midi', fp = "test_output.mid")
# Out:
# 'test_output.mid'

# %%
midi_stream.show('midi')
# Out:
#                 <div id='midiPlayerDiv162578'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv162578');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
